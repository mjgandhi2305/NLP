# %%
import collections

# %%
def load_words(filename="brown_nouns.txt"):
    """Reads words from the specified file and returns a clean list."""
    with open(filename, 'r') as f:
        words = [line.strip().lower() for line in f.readlines()]
    # Return a sorted list of unique words
    return sorted(list(set(words)))

words = load_words()
print(f"Loaded {len(words)} unique words.")
print("Sample words:", words[15:25])
# Out:
# Loaded 17892 unique words.
# Sample words: ['$.86', '$.90', '$0.9', '$1,000', '$1,000,000', '$1,000,000,000', '$1,200', '$1,250,000', '$1,276', '$1,390']

# %%
class TrieNode:
    """A node in the Trie structure."""
    def __init__(self):
        self.children = collections.defaultdict(TrieNode)
        self.is_end_of_word = False
        # This is our frequency measure.
        self.count = 0

class Trie:
    """The main Trie class."""
    def __init__(self):
        self.root = TrieNode()

    def insert(self, word):
        """Inserts a word into the trie, updating frequency counts."""
        node = self.root
        for char in word:
            node = node.children[char]
            # Increment the count for every node in the path.
            node.count += 1
        node.is_end_of_word = True

    def build_trie(self, word_list):
        """Builds the trie from a list of words."""
        for word in word_list:
            self.insert(word)

# %%
def stem_with_prefix_trie(word, trie):
    """
    Finds the stem and suffix of a word using a pre-built prefix trie.
    """
    node = trie.root
    path = []
    max_score = -1
    split_index = -1

    # We don't consider the root or the final leaf node as split points
    for i, char in enumerate(word[:-1]):
        if char not in node.children:
            return word, "" # Should not happen if trie is built correctly
        node = node.children[char]
        path.append(char)

        # Calculate the split score using our frequency-based heuristic
        branching_factor = len(node.children)
        frequency = node.count
        score = branching_factor * frequency

        # A split point is only valid if there's actual branching
        if score > max_score and branching_factor > 1:
            max_score = score
            split_index = i + 1

    if split_index != -1:
        stem = word[:split_index]
        suffix = word[split_index:]
        return stem, suffix
    else:
        # No suitable split point found
        return word, ""

# 1. Build the Prefix Trie
prefix_trie = Trie()
prefix_trie.build_trie(words)

# 2. Stem a few example words and print the output
print("--- Prefix Trie Stemming Results ---")
test_words = ['goes', 'kites', 'processes', 'processing', 'cars']
for word in test_words:
    stem, suffix = stem_with_prefix_trie(word, prefix_trie)
    if suffix:
        print(f"{word}={stem}+{suffix}")
    else:
        print(f"{word}={stem}")
# Out:
# --- Prefix Trie Stemming Results ---
# goes=goes
# kites=k+ites
# processes=p+rocesses
# processing=p+rocessing
# cars=c+ars

# %%
def stem_with_suffix_trie(word, trie):
    """
    Finds the stem and suffix of a word using a pre-built suffix trie.
    Note: The trie must be built with reversed words.
    """
    reversed_word = word[::-1]
    node = trie.root
    max_score = -1
    split_len_suffix = 0 # Length of the suffix

    # Traverse the trie with the reversed word
    for i, char in enumerate(reversed_word[:-1]):
        if char not in node.children:
            return word, ""
        node = node.children[char]

        # Calculate score using our frequency-based heuristic
        branching_factor = len(node.children)
        frequency = node.count
        score = branching_factor * frequency

        # If this is a better split point, update it
        if score > max_score and branching_factor > 1:
            max_score = score
            split_len_suffix = i + 1

    if split_len_suffix > 0:
        # The suffix is the first 'split_len_suffix' chars of the reversed word,
        # reversed back to normal.
        suffix = reversed_word[:split_len_suffix][::-1]
        stem = word[:-split_len_suffix]
        # Avoid creating stems that are too short (e.g., 'go' -> 'g'+'o')
        if len(stem) > 2:
            return stem, suffix
        else:
            return word, ""
    else:
        return word, ""

# 1. Build the Suffix Trie with reversed words
suffix_trie = Trie()
reversed_words = [w[::-1] for w in words]
suffix_trie.build_trie(reversed_words)


# 2. Stem all words and print the output
print("--- Suffix Trie Stemming Results ---")
for word in words:
    stem, suffix = stem_with_suffix_trie(word, suffix_trie)
    if suffix:
        print(f"{word}={stem}+{suffix}")
# Out:
# --- Suffix Trie Stemming Results ---
# $.027=$.02+7
# $.03=$.0+3
# $.054/mbf=$.054/mb+f
# $.07=$.0+7
# $.07/cwt=$.07/cw+t
# $.076=$.07+6
# $.09=$.0+9
# $.105=$.10+5
# $.12=$.1+2
# $.30=$.3+0
# $.30/mbf=$.30/mb+f
# $.50=$.5+0
# $.65=$.6+5
# $.75=$.7+5
# $.80=$.8+0
# $.86=$.8+6
# $.90=$.9+0
# $0.9=$0.+9
# $1,000=$1,00+0
# $1,000,000=$1,000,00+0
# $1,000,000,000=$1,000,000,00+0
# $1,200=$1,20+0
# $1,250,000=$1,250,00+0
# $1,276=$1,27+6
# $1,390=$1,39+0
# $1,450,000,000=$1,450,000,00+0
# $1,500=$1,50+0
# $1,500,000=$1,500,00+0
# $1,600=$1,60+0
# $1,750,000=$1,750,00+0
# $1,800=$1,80+0
# $1,961,000=$1,961,00+0
# $1.0=$1.+0
# $1.00=$1.0+0
# $1.1=$1.+1
# $1.10=$1.1+0
# $1.26=$1.2+6
# $1.4=$1.+4
# $1.5=$1.+5
# $1.6=$1.+6
# $1.60=$1.6+0
# $1.65=$1.6+5
# $1.7=$1.+7
# $1.8=$1.+8
# $1.80=$1.8+0
# $1.9=$1.+9
# $10,000=$10,00+0
# $10,000,000=$10,000,00+0
# $10.00=$10.0+0
# $10.1=$10.+1
# $10.3=$10.+3
# $10.50=$10.5+0
# $10.8=$10.+8
# $100=$10+0
# $100,000=$100,00+0
# $102,285,000=$102,285,00+0
# $1020=$102+0
# $109=$10+9
# $11,900,000=$11,900,00+0
# $11.50=$11.5+0
# $110=$11+0
# $115,000=$115,00+0
# $12,192,865=$12,192,86+5
# $12,500=$12,50+0
# $12.00=$12.0+0
# $12.1=$12.+1
# $12.50=$12.5+0
# $12.7=$12.+7
# $120=$12+0
# $125=$12+5
# $128=$12+8
# $133=$13+3
# $135=$13+5
# $139.3=$139.+3
# $14,000=$14,00+0
# $14.00=$14.0+0
# $140=$14+0
# $148.50=$148.5+0
# $15,000=$15,00+0
# $15,000,000=$15,000,00+0
# $15.5=$15.+5
# $150=$15+0
# $1500=$150+0
# $157,460=$157,46+0
# $16,000=$16,00+0
# $16.00=$16.0+0
# $16.80=$16.8+0
# $165=$16+5
# $17,000=$17,00+0
# $17,000,000=$17,000,00+0
# $17.8=$17.+8
# $170=$17+0
# $172,000=$172,00+0
# $172,400=$172,40+0
# $18.2=$18.+2
# $18.9=$18.+9
# $184=$18+4
# $185=$18+5
# $187=$18+7
# $19.3=$19.+3
# $2,000=$2,00+0
# $2,000,000=$2,000,00+0
# $2,170=$2,17+0
# $2,300=$2,30+0
# $2,300,000=$2,300,00+0
# $2,323,867=$2,323,86+7
# $2,330,000=$2,330,00+0
# $2,412,616=$2,412,61+6
# $2,461,000=$2,461,00+0
# $2,490=$2,49+0
# $2,500=$2,50+0
# $2,557,111=$2,557,11+1
# $2,700=$2,70+0
# $2.00=$2.0+0
# $2.09=$2.0+9
# $2.30/mbf=$2.30/mb+f
# $2.50=$2.5+0
# $2.80=$2.8+0
# $2.82=$2.8+2
# $2.98=$2.9+8
# $20,000=$20,00+0
# $20,000,000=$20,000,00+0
# $20,000,000,000=$20,000,000,00+0
# $20,447,000=$20,447,00+0
# $200=$20+0
# $200,000=$200,00+0
# $200,000,000=$200,000,00+0
# $214=$21+4
# $22.50=$22.5+0
# $222=$22+2
# $227.72=$227.7+2
# $23,000,000=$23,000,00+0
# $230,000=$230,00+0
# $24,926,615=$24,926,61+5
# $2400=$240+0
# $25,000=$25,00+0
# $250=$25+0
# $250,000=$250,00+0
# $2500=$250+0
# $251=$25+1
# $253,355,000=$253,355,00+0
# $26,000,000=$26,000,00+0
# $27.50=$27.5+0
# $278,877,000=$278,877,00+0
# $28,700,000=$28,700,00+0
# $28.00=$28.0+0
# $29,000=$29,00+0
# $297=$29+7
# $3,000=$3,00+0
# $3,500=$3,50+0
# $3,500,000=$3,500,00+0
# $3,675=$3,67+5
# $3,825=$3,82+5
# $3.00=$3.0+0
# $3.11=$3.1+1
# $3.15=$3.1+5
# $3.22=$3.2+2
# $3.5=$3.+5
# $3.50=$3.5+0
# $30,000=$30,00+0
# $30,000,000=$30,000,00+0
# $300=$30+0
# $300,000=$300,00+0
# $300,000,000=$300,000,00+0
# $306=$30+6
# $31,179,816=$31,179,81+6
# $310=$31+0
# $3100=$310+0
# $32,000=$32,00+0
# $325=$32+5
# $344,000=$344,00+0
# $35,823=$35,82+3
# $350=$35+0
# $350,000=$350,00+0
# $37,500=$37,50+0
# $380=$38+0
# $39,000=$39,00+0
# $39.5=$39.+5
# $395,000=$395,00+0
# $4,000=$4,00+0
# $4,000,000=$4,000,00+0
# $4,177.37=$4,177.3+7
# $4,500=$4,50+0
# $4,500,000=$4,500,00+0
# $4,700=$4,70+0
# $4,753=$4,75+3
# $4,800=$4,80+0
# $4.9=$4.+9
# $4.98=$4.9+8
# $4/mbf=$4/mb+f
# $40,000=$40,00+0
# $40,000,000=$40,000,00+0
# $400=$40+0
# $4200=$420+0
# $43,000=$43,00+0
# $43.50=$43.5+0
# $450=$45+0
# $450,000=$450,00+0
# $451,500=$451,50+0
# $457,000=$457,00+0
# $46.7=$46.+7
# $47,101,000=$47,101,00+0
# $5,000=$5,00+0
# $5,000,000=$5,000,00+0
# $5.2=$5.+2
# $5.4=$5.+4
# $50,000=$50,00+0
# $50,400,000=$50,400,00+0
# $500=$50+0
# $500,000=$500,00+0
# $5000=$500+0
# $52,500=$52,50+0
# $538=$53+8
# $55,000=$55,00+0
# $550=$55+0
# $57,500=$57,50+0
# $58,918=$58,91+8
# $580=$58+0
# $581=$58+1
# $581,000=$581,00+0
# $590,000=$590,00+0
# $6,100,000,000=$6,100,000,00+0
# $6,666.66=$6,666.6+6
# $60,000=$60,00+0
# $600=$60+0
# $610=$61+0
# $625,561=$625,56+1
# $63.8=$63.+8
# $634,517,000=$634,517,00+0
# $639=$63+9
# $65,000=$65,00+0
# $650=$65+0
# $66,000=$66,00+0
# $67,000=$67,00+0
# $7,000=$7,00+0
# $7,000,000=$7,000,00+0
# $7,082=$7,08+2
# $7,500,000=$7,500,00+0
# $7.00=$7.0+0
# $7.20=$7.2+0
# $7.50=$7.5+0
# $70,000=$70,00+0
# $700=$70+0
# $720=$72+0
# $73.50=$73.5+0
# $740=$74+0
# $740,000=$740,00+0
# $75,000,000=$75,000,00+0
# $750=$75+0
# $750,000=$750,00+0
# $754=$75+4
# $77,389,000=$77,389,00+0
# $79.89=$79.8+9
# $8,250=$8,25+0
# $8,313,514=$8,313,51+4
# $8,555=$8,55+5
# $8.00=$8.0+0
# $8.5=$8.+5
# $8.50=$8.5+0
# $80,738=$80,73+8
# $800=$80+0
# $800,000=$800,00+0
# $83,750=$83,75+0
# $84,000,000=$84,000,00+0
# $840,000=$840,00+0
# $842,617=$842,61+7
# $85,000=$85,00+0
# $88,000=$88,00+0
# $9,841,000=$9,841,00+0
# $9.2=$9.+2
# $9.50=$9.5+0
# $900=$90+0
# '20's='20'+s
# '20s='20+s
# '30s='30+s
# '40's='40'+s
# '50's='50'+s
# '60s='60+s
# '80's='80'+s
# '90s='90+s
# 'thirties='thirtie+s
# **ya=**y+a
# **yb=**y+b
# **yc=**y+c
# **ye=**y+e
# **yf=**y+f
# **yg=**y+g
# **yl=**y+l
# **ym=**y+m
# **ymg=**ym+g
# **yp=**y+p
# **yr=**y+r
# **yt=**y+t
# **zg=**z+g
# **zq=**z+q
# 0.002''=0.002+''
# 0.3m=0.3+m
# 0.5''=0.5+''
# 0.85%=0.85+%
# 1.25%=1.25+%
# 1.8%=1.8+%
# 1/16''=1/16+''
# 1/2''=1/2+''
# 1/4''=1/4+''
# 1/8''=1/8+''
# 10.6%=10.6+%
# 10.8%=10.8+%
# 100%=100+%
# 129%=129+%
# 1700's=1700'+s
# 1770's=1770'+s
# 18'.5=18'.+5
# 1800's=1800'+s
# 1840's=1840'+s
# 1850's=1850'+s
# 1860's=1860'+s
# 1870's=1870'+s
# 1880s=1880+s
# 1890's=1890'+s
# 1890s=1890+s
# 1900's=1900'+s
# 1920's=1920'+s
# 1920s=1920+s
# 1930's=1930'+s
# 1930s=1930+s
# 1940's=1940'+s
# 1940s=1940+s
# 1950's=1950'+s
# 1950s=1950+s
# 1960's=1960'+s
# 1960s=1960+s
# 1970s=1970+s
# 2.295%=2.295+%
# 2.325%=2.325+%
# 2.5%=2.5+%
# 21/64''=21/64+''
# 237%=237+%
# 242%=242+%
# 25.1%=25.1+%
# 3.25''=3.25+''
# 3.5%=3.5+%
# 3/16''=3/16+''
# 3/64''=3/64+''
# 320tr=320t+r
# 340tr=340t+r
# 47.1%=47.1+%
# 5/16''=5/16+''
# 5/64''=5/64+''
# 58.8%=58.8+%
# 6'.7=6'.+7
# 60's=60'+s
# 61.2%=61.2+%
# 7.6%=7.6+%
# 7/16''=7/16+''
# 70's=70'+s
# 742c=742+c
# 80's=80'+s
# 9/32''=9/32+''
# aab/=aab+/
# abandon=abando+n
# abandonment=abandonmen+t
# abaringe=abaring+e
# abasement=abasemen+t
# abberations=abberation+s
# abbey=abbe+y
# abbot=abbo+t
# abbreviation=abbreviatio+n
# abbreviations=abbreviation+s
# abdomen=abdome+n
# abdominis=abdomini+s
# abduction=abductio+n
# aberration=aberratio+n
# aberrations=aberration+s
# abeyance=abeyanc+e
# abilities=abilitie+s
# ability=abilit+y
# abjection=abjectio+n
# ablation=ablatio+n
# abnormalities=abnormalitie+s
# abode=abod+e
# abolition=abolitio+n
# abolitionist=abolitionis+t
# abolitionists=abolitionist+s
# aborigine=aborigin+e
# aborigines=aborigine+s
# abortion=abortio+n
# abortions=abortion+s
# abreaction=abreactio+n
# abridgment=abridgmen+t
# abruptness=abruptnes+s
# abscesses=abscesse+s
# abscissa=absciss+a
# absence=absenc+e
# absences=absence+s
# absentee=absente+e
# absenteeism=absenteeis+m
# absentia=absenti+a
# absinthe=absinth+e
# absolute=absolut+e
# absoluteness=absolutenes+s
# absolutes=absolute+s
# absolution=absolutio+n
# absorbency=absorbenc+y
# absorber=absorb+er
# absorption=absorptio+n
# absorptions=absorption+s
# abstention=abstentio+n
# abstinence=abstinenc+e
# abstract=abstrac+t
# abstractedness=abstractednes+s
# abstraction=abstractio+n
# abstractionism=abstractionis+m
# abstractionists=abstractionist+s
# abstractions=abstraction+s
# abstractors=abstractor+s
# abstracts=abstract+s
# abstrusenesses=abstrusenesse+s
# absurdities=absurditie+s
# absurdity=absurdit+y
# abundance=abundanc+e
# abuse=abus+e
# abuses=abuse+s
# abutments=abutment+s
# abyss=abys+s
# acacia=acaci+a
# academeh=academe+h
# academic=academi+c
# academics=academic+s
# academies=academie+s
# academy=academ+y
# acceleration=acceleratio+n
# accelerations=acceleration+s
# accelerator=accelerato+r
# accelerators=accelerator+s
# accelerometer=acceleromet+er
# accelerometers=accelerometer+s
# accent=accen+t
# accenting=accent+ing
# accents=accent+s
# acceptability=acceptabilit+y
# acceptance=acceptanc+e
# access=acces+s
# accesses=accesse+s
# accessibility=accessibilit+y
# accessions=accession+s
# accessories=accessorie+s
# accessory=accessor+y
# accident=acciden+t
# accidents=accident+s
# acclaim=acclai+m
# acclamation=acclamatio+n
# accolade=accolad+e
# accolades=accolade+s
# accommodation=accommodatio+n
# accommodations=accommodation+s
# accomodations=accomodation+s
# accompaniment=accompanimen+t
# accompaniments=accompaniment+s
# accompanist=accompanis+t
# accompanists=accompanist+s
# accomplice=accomplic+e
# accomplices=accomplice+s
# accomplishment=accomplishmen+t
# accomplishments=accomplishment+s
# accord=accor+d
# accordance=accordanc+e
# accordion=accordio+n
# account=accoun+t
# accountability=accountabilit+y
# accountant=accountan+t
# accountants=accountant+s
# accounting=account+ing
# accounts=account+s
# accouterments=accouterment+s
# accreditation=accreditatio+n
# accretion=accretio+n
# accretions=accretion+s
# acculturation=acculturatio+n
# accumulation=accumulatio+n
# accuracy=accurac+y
# accusation=accusatio+n
# accusations=accusation+s
# aces=ace+s
# acetate=acetat+e
# acetone=aceton+e
# acetonemia=acetonemi+a
# ache=ach+e
# achievement=achievemen+t
# achievements=achievement+s
# acid=aci+d
# acidity=acidit+y
# acids=acid+s
# acknowledgement=acknowledgemen+t
# acknowledgment=acknowledgmen+t
# acknowledgments=acknowledgment+s
# acolyte=acolyt+e
# aconte=acont+e
# acorns=acorn+s
# acoustics=acoustic+s
# acquaintance=acquaintanc+e
# acquiescence=acquiescenc+e
# acquiesence=acquiesenc+e
# acquisition=acquisitio+n
# acquisitions=acquisition+s
# acquisitiveness=acquisitivenes+s
# acquittal=acquitta+l
# acre=acr+e
# acreage=acreag+e
# acres=acre+s
# acrobacy=acrobac+y
# acrobatics=acrobatic+s
# acrobats=acrobat+s
# acrylic=acryli+c
# acting=act+ing
# actinometer=actinomet+er
# action=actio+n
# actions=action+s
# activation=activatio+n
# active=activ+e
# actives=active+s
# activism=activis+m
# activities=activitie+s
# activity=activit+y
# actor=acto+r
# actors=actor+s
# actress=actres+s
# actresses=actresse+s
# acts=act+s
# actualities=actualitie+s
# actuality=actualit+y
# acumen=acume+n
# adage=adag+e
# adagio=adagi+o
# adagios=adagio+s
# adaptation=adaptatio+n
# adaptations=adaptation+s
# adapter=adapt+er
# adapters=adapter+s
# adapting=adapt+ing
# addiction=addictio+n
# addicts=addict+s
# adding=add+ing
# addition=additio+n
# additions=addition+s
# additive=additiv+e
# additives=additive+s
# address=addres+s
# addressees=addressee+s
# addresses=addresse+s
# adenomas=adenoma+s
# adequacy=adequac+y
# adherence=adherenc+e
# adherent=adheren+t
# adherents=adherent+s
# adhesion=adhesio+n
# adhesive=adhesiv+e
# adhesives=adhesive+s
# adjective=adjectiv+e
# adjectives=adjective+s
# adjournment=adjournmen+t
# adjudication=adjudicatio+n
# adjunct=adjunc+t
# adjuncts=adjunct+s
# adjustment=adjustmen+t
# adjustments=adjustment+s
# administration=administratio+n
# administrator=administrato+r
# administrators=administrator+s
# adminstration=adminstratio+n
# admirals=admiral+s
# admiralty=admiralt+y
# admiration=admiratio+n
# admirer=admir+er
# admirers=admirer+s
# admission=admissio+n
# admissions=admission+s
# admittance=admittanc+e
# admonishments=admonishment+s
# admonition=admonitio+n
# admonitions=admonition+s
# adobe=adob+e
# adolescence=adolescenc+e
# adolescent=adolescen+t
# adolescents=adolescent+s
# adoption=adoptio+n
# adrenal=adrena+l
# adroitness=adroitnes+s
# adulation=adulatio+n
# adult=adul+t
# adulterers=adulterer+s
# adultery=adulter+y
# adulthood=adulthoo+d
# adults=adult+s
# advance=advanc+e
# advancement=advancemen+t
# advancements=advancement+s
# advances=advance+s
# advantage=advantag+e
# advantages=advantage+s
# advent=adven+t
# adventure=adventur+e
# adventurers=adventurer+s
# adventures=adventure+s
# adverb=adver+b
# adverbs=adverb+s
# adversaries=adversarie+s
# adversary=adversar+y
# adversity=adversit+y
# advertisement=advertisemen+t
# advertisements=advertisement+s
# advertisers=advertiser+s
# advertising=advertis+ing
# advice=advic+e
# advisability=advisabilit+y
# advisement=advisemen+t
# adviser=advis+er
# advisers=adviser+s
# advisor=adviso+r
# advisors=advisor+s
# advisory=advisor+y
# advocacy=advocac+y
# advocate=advocat+e
# advocates=advocate+s
# aec's=aec'+s
# aegis=aegi+s
# aeon=aeo+n
# aeration=aeratio+n
# aerator=aerato+r
# aerials=aerial+s
# aerosol=aeroso+l
# aerosols=aerosol+s
# aesthetes=aesthete+s
# aesthetic=aestheti+c
# aesthetics=aesthetic+s
# affair=affai+r
# affairs=affair+s
# affect=affec+t
# affectation=affectatio+n
# affection=affectio+n
# affections=affection+s
# affects=affect+s
# affidavits=affidavit+s
# affiliates=affiliate+s
# affiliation=affiliatio+n
# affiliations=affiliation+s
# affinities=affinitie+s
# affinity=affinit+y
# affirmation=affirmatio+n
# affirmations=affirmation+s
# affliction=afflictio+n
# afflictions=affliction+s
# affluence=affluenc+e
# affront=affron+t
# afghan=afgha+n
# aficionado=aficionad+o
# aftermath=aftermat+h
# afternoon=afternoo+n
# afternoons=afternoon+s
# agates=agate+s
# agencies=agencie+s
# agency=agenc+y
# agenda=agend+a
# agent=agen+t
# agents=agent+s
# ages=age+s
# agglomeration=agglomeratio+n
# agglutination=agglutinatio+n
# agglutinin=agglutini+n
# agglutinins=agglutinin+s
# aggregate=aggregat+e
# aggregation=aggregatio+n
# aggregations=aggregation+s
# aggression=aggressio+n
# aggressions=aggression+s
# aggressiveness=aggressivenes+s
# aggressor=aggresso+r
# agility=agilit+y
# agitation=agitatio+n
# agitator=agitato+r
# agitators=agitator+s
# agnomen=agnome+n
# agnostics=agnostic+s
# agonies=agonie+s
# agony=agon+y
# agrarian=agraria+n
# agreeableness=agreeablenes+s
# agreement=agreemen+t
# agreements=agreement+s
# agriculture=agricultur+e
# ague=agu+e
# aiche=aich+e
# aid's=aid'+s
# aide=aid+e
# aides=aide+s
# aids=aid+s
# aiee=aie+e
# ailerons=aileron+s
# ailment=ailmen+t
# ailments=ailment+s
# aimo=aim+o
# aims=aim+s
# aircraft=aircraf+t
# airdrops=airdrop+s
# airfield=airfiel+d
# airfields=airfield+s
# airflow=airfl+ow
# airframe=airfram+e
# airlift=airlif+t
# airline=airlin+e
# airlines=airline+s
# airlock=airloc+k
# airmail=airmai+l
# airmen=airme+n
# airplane=airplan+e
# airplanes=airplane+s
# airport=airpor+t
# airports=airport+s
# airs=air+s
# airspeed=airspee+d
# airstrip=airstri+p
# airstrips=airstrip+s
# airways=airway+s
# aisle=aisl+e
# alabaster=alabast+er
# alarm=alar+m
# alarms=alarm+s
# album=albu+m
# albumin=albumi+n
# albums=album+s
# alchemy=alchem+y
# alcohol=alcoho+l
# alcoholics=alcoholic+s
# alcoholism=alcoholis+m
# alcohols=alcohol+s
# alcoves=alcove+s
# alderman=alderma+n
# aldermen=alderme+n
# aleck=alec+k
# alert=aler+t
# alertness=alertnes+s
# alfresco=alfresc+o
# algae=alga+e
# algaecide=algaecid+e
# algebra=algebr+a
# alginates=alginate+s
# algorithm=algorith+m
# alias=alia+s
# alibi=alib+i
# alibis=alibi+s
# alien=alie+n
# alienation=alienatio+n
# aliens=alien+s
# alignment=alignmen+t
# alignments=alignment+s
# alimony=alimon+y
# aliquots=aliquot+s
# alizarin=alizari+n
# alkali=alkal+i
# alkalis=alkali+s
# alkaloids=alkaloid+s
# alkylbenzenesulfonates=alkylbenzenesulfonate+s
# allay=alla+y
# allegations=allegation+s
# allegiance=allegianc+e
# allegiances=allegiance+s
# allegory=allegor+y
# allergies=allergie+s
# allergy=allerg+y
# alleviation=alleviatio+n
# alley=alle+y
# alleys=alley+s
# alleyways=alleyway+s
# alliance=allianc+e
# alliances=alliance+s
# allies=allie+s
# alligator=alligato+r
# alliteration=alliteratio+n
# allocation=allocatio+n
# allocations=allocation+s
# allotment=allotmen+t
# allotments=allotment+s
# allowance=allowanc+e
# allowances=allowance+s
# alloy=allo+y
# alloys=alloy+s
# allure=allur+e
# allurement=alluremen+t
# allusion=allusio+n
# allusions=allusion+s
# allusiveness=allusivenes+s
# ally=all+y
# almond=almon+d
# almonds=almond+s
# aloes=aloe+s
# aloneness=alonenes+s
# aloofness=aloofnes+s
# alphabet=alphabe+t
# altar=alta+r
# alteration=alteratio+n
# alterations=alteration+s
# altercation=altercatio+n
# alternate=alternat+e
# alternation=alternatio+n
# alternative=alternativ+e
# alternatives=alternative+s
# altitude=altitud+e
# alto=alt+o
# altruism=altruis+m
# alum=alu+m
# aluminum=aluminu+m
# alumnae=alumna+e
# alumni=alumn+i
# alundum=alundu+m
# alveoli=alveol+i
# alveolus=alveolu+s
# amalgamation=amalgamatio+n
# amanuensis=amanuensi+s
# amassing=amass+ing
# amateur=amateu+r
# amateurishness=amateurishnes+s
# amateurs=amateur+s
# amazement=amazemen+t
# amazons=amazon+s
# ambassador=ambassado+r
# ambassadors=ambassador+s
# ambiance=ambianc+e
# ambiguities=ambiguitie+s
# ambiguity=ambiguit+y
# ambition=ambitio+n
# ambitions=ambition+s
# ambivalence=ambivalenc+e
# ambulance=ambulanc+e
# ambulances=ambulance+s
# ambuscade=ambuscad+e
# ambush=ambus+h
# ambushes=ambushe+s
# amendment=amendmen+t
# amendments=amendment+s
# amethystine=amethystin+e
# amide=amid+e
# amines=amine+s
# amino=amin+o
# amity=amit+y
# ammo=amm+o
# ammonium=ammoniu+m
# ammunition=ammunitio+n
# amorality=amoralit+y
# amorist=amoris+t
# amortization=amortizatio+n
# amount=amoun+t
# amounts=amount+s
# amphetamines=amphetamine+s
# amphibology=amphibolog+y
# amphitheater=amphitheat+er
# amplification=amplificatio+n
# amplifier=amplifi+er
# amplifiers=amplifier+s
# amplitude=amplitud+e
# amulet=amule+t
# amulets=amulet+s
# amusement=amusemen+t
# amusements=amusement+s
# anachronism=anachronis+m
# anachronisms=anachronism+s
# anaconda=anacond+a
# anacondas=anaconda+s
# anaesthesia=anaesthesi+a
# anagram=anagra+m
# analogies=analogie+s
# analogue=analogu+e
# analogues=analogue+s
# analogy=analog+y
# analyses=analyse+s
# analysis=analysi+s
# analyst=analys+t
# analysts=analyst+s
# analyticity=analyticit+y
# anaplasmosis=anaplasmosi+s
# anaprapath=anaprapat+h
# anarchist=anarchis+t
# anarchy=anarch+y
# anastomoses=anastomose+s
# anastomosis=anastomosi+s
# anatomical=anatomica+l
# anatomicals=anatomical+s
# anatomy=anatom+y
# ancestor=ancesto+r
# ancestors=ancestor+s
# ancestry=ancestr+y
# anchor=ancho+r
# anchorage=anchorag+e
# anchoritism=anchoritis+m
# anchors=anchor+s
# anchovy=anchov+y
# ancient=ancien+t
# ancients=ancient+s
# andrena=andren+a
# andrenas=andrena+s
# anecdote=anecdot+e
# anecdotes=anecdote+s
# anemia=anemi+a
# anesthetic=anestheti+c
# anesthetics=anesthetic+s
# angel=ange+l
# angelica=angelic+a
# angels=angel+s
# anger=ang+er
# angle=angl+e
# angles=angle+s
# anglophilia=anglophili+a
# anglophobia=anglophobi+a
# anguish=anguis+h
# aniline=anilin+e
# animal=anima+l
# animals=animal+s
# animation=animatio+n
# animism=animis+m
# animosity=animosit+y
# anion=anio+n
# anionics=anionic+s
# anions=anion+s
# anise=anis+e
# anisotropy=anisotrop+y
# ankle=ankl+e
# ankles=ankle+s
# annals=annal+s
# annihilation=annihilatio+n
# anniversaries=anniversarie+s
# anniversary=anniversar+y
# announcement=announcemen+t
# announcements=announcement+s
# announcer=announc+er
# announcers=announcer+s
# annoyance=annoyanc+e
# annoyances=annoyance+s
# annual=annua+l
# annum=annu+m
# anode=anod+e
# anodes=anode+s
# anomalies=anomalie+s
# anomaly=anomal+y
# anomie=anomi+e
# anonymity=anonymit+y
# anorexia=anorexi+a
# answer=answ+er
# answers=answer+s
# antagonism=antagonis+m
# antagonisms=antagonism+s
# antagonist=antagonis+t
# antagonists=antagonist+s
# ante=ant+e
# anteater=anteat+er
# antecedent=anteceden+t
# antecedents=antecedent+s
# antelope=antelop+e
# antenna=antenn+a
# antennae=antenna+e
# antennas=antenna+s
# anteriors=anterior+s
# anthems=anthem+s
# anthology=antholog+y
# anthropologist=anthropologis+t
# anthropologists=anthropologist+s
# anthropology=anthropolog+y
# antibiotic=antibioti+c
# antibiotics=antibiotic+s
# antibodies=antibodie+s
# antibody=antibod+y
# anticipation=anticipatio+n
# anticipations=anticipation+s
# anticoagulation=anticoagulatio+n
# antics=antic+s
# antidote=antidot+e
# antifundamentalist=antifundamentalis+t
# antigen=antige+n
# antipathy=antipath+y
# antipodes=antipode+s
# antiquarians=antiquarian+s
# antique=antiqu+e
# antiques=antique+s
# antiquities=antiquitie+s
# antiquity=antiquit+y
# antiredeposition=antiredepositio+n
# antiseptic=antisepti+c
# antisera=antiser+a
# antiserum=antiseru+m
# antithesis=antithesi+s
# ants=ant+s
# anvil=anvi+l
# anxieties=anxietie+s
# anxiety=anxiet+y
# aorta=aort+a
# apartheid=aparthei+d
# apartment=apartmen+t
# apartments=apartment+s
# apathy=apath+y
# aperture=apertur+e
# apex=ape+x
# aplomb=aplom+b
# apocalypse=apocalyps+e
# apogee=apoge+e
# apologetic=apologeti+c
# apologies=apologie+s
# apologist=apologis+t
# apology=apolog+y
# apostates=apostate+s
# apostle=apostl+e
# apostles=apostle+s
# apothecary=apothecar+y
# apotheosis=apotheosi+s
# appanage=appanag+e
# apparatus=apparatu+s
# apparel=appare+l
# apparency=apparenc+y
# apparition=apparitio+n
# appeal=appea+l
# appeals=appeal+s
# appearance=appearanc+e
# appearances=appearance+s
# appeasement=appeasemen+t
# appendages=appendage+s
# appestat=appesta+t
# appetite=appetit+e
# appetites=appetite+s
# applause=applaus+e
# apple=appl+e
# applejack=applejac+k
# apples=apple+s
# appliance=applianc+e
# appliances=appliance+s
# applicability=applicabilit+y
# applicant=applican+t
# applicants=applicant+s
# application=applicatio+n
# applications=application+s
# applicator=applicato+r
# appliques=applique+s
# appointee=appointe+e
# appointees=appointee+s
# appointment=appointmen+t
# appointments=appointment+s
# apportionment=apportionmen+t
# apportionments=apportionment+s
# appraisal=appraisa+l
# appraisals=appraisal+s
# appraisers=appraiser+s
# appreciation=appreciatio+n
# appreciations=appreciation+s
# apprehension=apprehensio+n
# apprehensions=apprehension+s
# apprentice=apprentic+e
# apprentices=apprentice+s
# apprenticeship=apprenticeshi+p
# approach=approac+h
# approaches=approache+s
# appropriateness=appropriatenes+s
# appropriation=appropriatio+n
# appropriations=appropriation+s
# approval=approva+l
# approximation=approximatio+n
# approximations=approximation+s
# apricot=aprico+t
# apron=apro+n
# aprons=apron+s
# apses=apse+s
# aptitude=aptitud+e
# aptitudes=aptitude+s
# aptness=aptnes+s
# aqueducts=aqueduct+s
# aquisition=aquisitio+n
# arabesque=arabesqu+e
# arak=ara+k
# arbiter=arbit+er
# arbitration=arbitratio+n
# arcade=arcad+e
# arcades=arcade+s
# arch=arc+h
# archaeologists=archaeologist+s
# archaeology=archaeolog+y
# archaism=archais+m
# archangels=archangel+s
# archbishop=archbisho+p
# archdiocese=archdioces+e
# archenemy=archenem+y
# archery=archer+y
# arches=arche+s
# archfool=archfoo+l
# archipelago=archipelag+o
# architect=architec+t
# architects=architect+s
# architecture=architectur+e
# architectures=architecture+s
# archives=archive+s
# archtype=archtyp+e
# arcs=arc+s
# arcus=arcu+s
# ardor=ardo+r
# area=are+a
# areas=area+s
# areaways=areaway+s
# arena=aren+a
# arenas=arena+s
# areosol=areoso+l
# argon=argo+n
# argot=argo+t
# argument=argumen+t
# argumentation=argumentatio+n
# arguments=argument+s
# aridity=aridit+y
# aristocracy=aristocrac+y
# aristocrats=aristocrat+s
# arithmetic=arithmeti+c
# armadillo=armadill+o
# armament=armamen+t
# armaments=armament+s
# armchair=armchai+r
# armchairs=armchair+s
# armful=armfu+l
# armhole=armhol+e
# armies=armie+s
# armistice=armistic+e
# armload=armloa+d
# armoire=armoir+e
# armor=armo+r
# armpit=armpi+t
# armpits=armpit+s
# arms=arm+s
# army=arm+y
# arnica=arnic+a
# aroma=arom+a
# aromas=aroma+s
# arousal=arousa+l
# arpeggios=arpeggio+s
# arrack=arrac+k
# arrangement=arrangemen+t
# arrangements=arrangement+s
# arrangers=arranger+s
# array=arra+y
# arrears=arrear+s
# arrest=arres+t
# arrests=arrest+s
# arrival=arriva+l
# arrivals=arrival+s
# arrogance=arroganc+e
# arrow=arr+ow
# arrowheads=arrowhead+s
# arrows=arrow+s
# arroyo=arroy+o
# arsenal=arsena+l
# arsenic=arseni+c
# arside=arsid+e
# arsines=arsine+s
# arson=arso+n
# arteries=arterie+s
# arterioles=arteriole+s
# arteriolosclerosis=arteriolosclerosi+s
# arteriosclerosis=arteriosclerosi+s
# artery=arter+y
# artfulness=artfulnes+s
# arthritis=arthriti+s
# article=articl+e
# articles=article+s
# articulation=articulatio+n
# articulations=articulation+s
# artifacts=artifact+s
# artifice=artific+e
# artificer=artific+er
# artificiality=artificialit+y
# artillerist=artilleris+t
# artillery=artiller+y
# artisan=artisa+n
# artisans=artisan+s
# artist=artis+t
# artistry=artistr+y
# artists=artist+s
# arts=art+s
# aryl=ary+l
# arylesterase=arylesteras+e
# arylesterases=arylesterase+s
# asbestos=asbesto+s
# ascendancy=ascendanc+y
# ascent=ascen+t
# ascetic=asceti+c
# asceticism=asceticis+m
# asdic=asdi+c
# ashes=ashe+s
# ashtrays=ashtray+s
# asme=asm+e
# asparagus=asparagu+s
# aspect=aspec+t
# aspects=aspect+s
# aspen=aspe+n
# asphalt=asphal+t
# aspirant=aspiran+t
# aspirants=aspirant+s
# aspiration=aspiratio+n
# aspirations=aspiration+s
# aspirin=aspiri+n
# aspr=asp+r
# assailant=assailan+t
# assailants=assailant+s
# assassin=assassi+n
# assassination=assassinatio+n
# assassins=assassin+s
# assault=assaul+t
# assaults=assault+s
# assay=assa+y
# assemblage=assemblag+e
# assemblages=assemblage+s
# assemblies=assemblie+s
# assembly=assembl+y
# assent=assen+t
# assertion=assertio+n
# assertions=assertion+s
# assertiveness=assertivenes+s
# asses=asse+s
# assesment=assesmen+t
# assessment=assessmen+t
# assessments=assessment+s
# assessor=assesso+r
# assessors=assessor+s
# asset=asse+t
# assets=asset+s
# assiduity=assiduit+y
# assignee=assigne+e
# assignment=assignmen+t
# assignments=assignment+s
# assimilation=assimilatio+n
# assist=assis+t
# assistance=assistanc+e
# assistant=assistan+t
# assistants=assistant+s
# assists=assist+s
# associate=associat+e
# associates=associate+s
# association=associatio+n
# associations=association+s
# assonance=assonanc+e
# assortment=assortmen+t
# assumption=assumptio+n
# assumptions=assumption+s
# assurance=assuranc+e
# assurances=assurance+s
# asterisks=asterisk+s
# asteroid=asteroi+d
# asters=aster+s
# asthma=asthm+a
# astonishment=astonishmen+t
# astringency=astringenc+y
# astronaut=astronau+t
# astronomer=astronom+er
# astronomy=astronom+y
# astrophysics=astrophysic+s
# astuteness=astutenes+s
# asymmetry=asymmetr+y
# asynchrony=asynchron+y
# atheists=atheist+s
# athlete=athlet+e
# athletes=athlete+s
# athleticism=athleticis+m
# athletics=athletic+s
# atmosphere=atmospher+e
# atmospheres=atmosphere+s
# atom=ato+m
# atomisation=atomisatio+n
# atoms=atom+s
# atonement=atonemen+t
# atrocities=atrocitie+s
# atrophy=atroph+y
# attachment=attachmen+t
# attachments=attachment+s
# attack=attac+k
# attacker=attack+er
# attackers=attacker+s
# attacks=attack+s
# attainment=attainmen+t
# attainments=attainment+s
# attempt=attemp+t
# attempts=attempt+s
# attendance=attendanc+e
# attendant=attendan+t
# attendants=attendant+s
# attention=attentio+n
# attentions=attention+s
# attic=atti+c
# attire=attir+e
# attitude=attitud+e
# attitudes=attitude+s
# attorney=attorne+y
# attorneys=attorney+s
# attraction=attractio+n
# attractions=attraction+s
# attribute=attribut+e
# attributes=attribute+s
# attrition=attritio+n
# auction=auctio+n
# auctioneer=auctione+er
# audacity=audacit+y
# audience=audienc+e
# audiences=audience+s
# audio=audi+o
# audit=audi+t
# audition=auditio+n
# auditions=audition+s
# auditor=audito+r
# auditorium=auditoriu+m
# auditors=auditor+s
# aunt=aun+t
# aunts=aunt+s
# aura=aur+a
# auspices=auspice+s
# austerity=austerit+y
# australites=australite+s
# authentication=authenticatio+n
# authentications=authentication+s
# authenticator=authenticato+r
# authenticity=authenticit+y
# author=autho+r
# authoritarianism=authoritarianis+m
# authorities=authoritie+s
# authority=authorit+y
# authorization=authorizatio+n
# authorizations=authorization+s
# authors=author+s
# authorship=authorshi+p
# autism=autis+m
# auto=aut+o
# autobiography=autobiograph+y
# autocollimator=autocollimato+r
# autocracies=autocracie+s
# autocrats=autocrat+s
# autofluorescence=autofluorescenc+e
# autograph=autograp+h
# autoloader=autoload+er
# automatic=automati+c
# automation=automatio+n
# automaton=automato+n
# automobile=automobil+e
# automobiles=automobile+s
# autonavigator=autonavigato+r
# autonomy=autonom+y
# autopsy=autops+y
# autos=auto+s
# autosuggestibility=autosuggestibilit+y
# autumn=autum+n
# auxiliaries=auxiliarie+s
# auxiliary=auxiliar+y
# avail=avai+l
# availabilities=availabilitie+s
# availability=availabilit+y
# avalanche=avalanch+e
# avarice=avaric+e
# avenue=avenu+e
# avenues=avenue+s
# average=averag+e
# averages=average+s
# averaging=averag+ing
# aversion=aversio+n
# aviary=aviar+y
# aviation=aviatio+n
# aviator=aviato+r
# aviators=aviator+s
# avidity=avidit+y
# avocado=avocad+o
# avocados=avocado+s
# avocation=avocatio+n
# avoidance=avoidanc+e
# awakening=awaken+ing
# award=awar+d
# awarding=award+ing
# awards=award+s
# awareness=awarenes+s
# awfulness=awfulnes+s
# awkwardness=awkwardnes+s
# awnings=awning+s
# awoc=awo+c
# axes=axe+s
# axiom=axio+m
# axioms=axiom+s
# axis=axi+s
# axle=axl+e
# axles=axle+s
# ayes=aye+s
# azalea=azale+a
# azaleas=azalea+s
# babel=babe+l
# babes=babe+s
# babies=babie+s
# baby=bab+y
# babyhood=babyhoo+d
# bachelor=bachelo+r
# bachelors=bachelor+s
# back=bac+k
# backbend=backben+d
# backbends=backbend+s
# backbone=backbon+e
# backdrop=backdro+p
# backers=backer+s
# background=backgroun+d
# backgrounds=background+s
# backing=back+ing
# backlash=backlas+h
# backlog=backlo+g
# backpack=backpac+k
# backs=back+s
# backside=backsid+e
# backstitch=backstitc+h
# backwoods=backwood+s
# backyard=backyar+d
# backyards=backyard+s
# bacon=baco+n
# bacteria=bacteri+a
# badge=badg+e
# badges=badge+s
# badinage=badinag+e
# badmen=badme+n
# badminton=badminto+n
# badness=badnes+s
# bads=bad+s
# baggage=baggag+e
# bagpipe=bagpip+e
# bags=bag+s
# bail=bai+l
# baileefe=baileef+e
# bailiff=bailif+f
# bailing=bail+ing
# bait=bai+t
# baker=bak+er
# bakery=baker+y
# baking=bak+ing
# balance=balanc+e
# balances=balance+s
# balancing=balanc+ing
# balconies=balconie+s
# balcony=balcon+y
# baldness=baldnes+s
# bale=bal+e
# bales=bale+s
# balkiness=balkines+s
# ball=bal+l
# ballad=balla+d
# ballads=ballad+s
# ballards=ballard+s
# ballast=ballas+t
# ballerina=ballerin+a
# ballerinas=ballerina+s
# ballet=balle+t
# balletomane=balletoman+e
# ballets=ballet+s
# ballfields=ballfield+s
# ballgowns=ballgown+s
# ballistics=ballistic+s
# balloon=balloo+n
# balloons=balloon+s
# ballot=ballo+t
# ballots=ballot+s
# ballplayer=ballplay+er
# ballplayers=ballplayer+s
# ballroom=ballroo+m
# balls=ball+s
# ballyhoo=ballyho+o
# ballyhooey=ballyhooe+y
# balsams=balsam+s
# balustrade=balustrad+e
# banana=banan+a
# bananas=banana+s
# band=ban+d
# bandage=bandag+e
# bandages=bandage+s
# bandit=bandi+t
# bandits=bandit+s
# bandoleers=bandoleer+s
# bands=band+s
# bandstand=bandstan+d
# bandwagon=bandwago+n
# bandwidth=bandwidt+h
# bang=ban+g
# banging=bang+ing
# bangs=bang+s
# banishment=banishmen+t
# banister=banist+er
# banisters=banister+s
# banjo=banj+o
# bank=ban+k
# banker=bank+er
# bankers=banker+s
# bankruptcy=bankruptc+y
# banks=bank+s
# banner=bann+er
# banners=banner+s
# banning=bann+ing
# banquet=banque+t
# banquetings=banqueting+s
# banquets=banquet+s
# banshee=banshe+e
# banshees=banshee+s
# banter=bant+er
# baptism=baptis+m
# baptisms=baptism+s
# baptistery=baptister+y
# bar'l=bar'+l
# barbarian=barbaria+n
# barbarians=barbarian+s
# barbecue=barbecu+e
# barbecues=barbecue+s
# barbell=barbel+l
# barber=barb+er
# barbital=barbita+l
# barbiturate=barbiturat+e
# barbs=barb+s
# bard=bar+d
# bards=bard+s
# barflies=barflie+s
# bargain=bargai+n
# bargaining=bargain+ing
# bargains=bargain+s
# barge=barg+e
# barges=barge+s
# baritone=bariton+e
# barium=bariu+m
# bark=bar+k
# barkeep=barkee+p
# barking=bark+ing
# barley=barle+y
# barn=bar+n
# barns=barn+s
# barnsful=barnsfu+l
# barnstormer=barnstorm+er
# barnyard=barnyar+d
# barnyards=barnyard+s
# baron=baro+n
# baroness=barones+s
# barons=baron+s
# barony=baron+y
# baroreceptor=barorecepto+r
# barrack=barrac+k
# barracks=barrack+s
# barrage=barrag+e
# barrel=barre+l
# barrels=barrel+s
# barricade=barricad+e
# barricades=barricade+s
# barrier=barri+er
# barriers=barrier+s
# bars=bar+s
# bartender=bartend+er
# base=bas+e
# baseball=basebal+l
# baseballight=baseballigh+t
# baseballs=baseball+s
# baseline=baselin+e
# baseman=basema+n
# basement=basemen+t
# basements=basement+s
# bases=base+s
# basics=basic+s
# basin=basi+n
# basis=basi+s
# basket=baske+t
# basketball=basketbal+l
# baskets=basket+s
# bass=bas+s
# basses=basse+s
# bassinet=bassine+t
# bastard=bastar+d
# bastards=bastard+s
# bastion=bastio+n
# batch=batc+h
# bateau=batea+u
# bath=bat+h
# bathers=bather+s
# bathos=batho+s
# bathrobe=bathrob+e
# bathroom=bathroo+m
# bathrooms=bathroom+s
# baths=bath+s
# bathtub=bathtu+b
# bathtubs=bathtub+s
# baton=bato+n
# bats=bat+s
# battalion=battalio+n
# battalions=battalion+s
# batten=batte+n
# battens=batten+s
# batter=batt+er
# batterie=batteri+e
# batteries=batterie+s
# batters=batter+s
# battery=batter+y
# battle=battl+e
# battlefield=battlefiel+d
# battlefields=battlefield+s
# battlefront=battlefron+t
# battleground=battlegroun+d
# battlements=battlement+s
# battles=battle+s
# batwings=batwing+s
# bauble=baubl+e
# bawh=baw+h
# bawhs=bawh+s
# baying=bay+ing
# bayleefe=bayleef+e
# bayly=bayl+y
# bayonet=bayone+t
# bayonets=bayonet+s
# bays=bay+s
# bazaar=bazaa+r
# bazaars=bazaar+s
# bd/ft=bd/f+t
# beach=beac+h
# beaches=beache+s
# beachhead=beachhea+d
# beacon=beaco+n
# bead=bea+d
# beadle=beadl+e
# beads=bead+s
# beadsman=beadsma+n
# beaker=beak+er
# beakers=beaker+s
# beam=bea+m
# beams=beam+s
# bean=bea+n
# beans=bean+s
# bear=bea+r
# beard=bear+d
# beards=beard+s
# bearer=bear+er
# bearing=bear+ing
# bearings=bearing+s
# beast=beas+t
# beasties=beastie+s
# beasts=beast+s
# beat=bea+t
# beatification=beatificatio+n
# beating=beat+ing
# beatings=beating+s
# beatnik=beatni+k
# beatniks=beatnik+s
# beats=beat+s
# beau=bea+u
# beauties=beautie+s
# beauty=beaut+y
# beaver=beav+er
# beavertail=beavertai+l
# bebop=bebo+p
# beckoning=beckon+ing
# becoming=becom+ing
# bedazzlement=bedazzlemen+t
# bedbugs=bedbug+s
# bedding=bedd+ing
# bedground=bedgroun+d
# bedlam=bedla+m
# bedpost=bedpos+t
# bedroom=bedroo+m
# bedrooms=bedroom+s
# beds=bed+s
# bedside=bedsid+e
# bedspread=bedsprea+d
# bedsprings=bedspring+s
# bedstraw=bedstra+w
# bedtime=bedtim+e
# beebread=beebrea+d
# beech=beec+h
# beef=bee+f
# beefsteak=beefstea+k
# beehive=beehiv+e
# beep=bee+p
# beeps=beep+s
# beers=beer+s
# bees=bee+s
# beetles=beetle+s
# beets=beet+s
# beggar=begga+r
# beggars=beggar+s
# beggary=beggar+y
# begging=begg+ing
# beginner=beginn+er
# beginners=beginner+s
# beginning=beginn+ing
# beginnings=beginning+s
# behalf=behal+f
# behavior=behavio+r
# behaviors=behavior+s
# behaviour=behaviou+r
# behind=behin+d
# beings=being+s
# belaboring=belabor+ing
# belch=belc+h
# belching=belch+ing
# belfry=belfr+y
# belief=belie+f
# beliefs=belief+s
# believer=believ+er
# believers=believer+s
# bell=bel+l
# bellboy=bellbo+y
# bellboys=bellboy+s
# belles=belle+s
# bellhops=bellhop+s
# bellicosity=bellicosit+y
# bellies=bellie+s
# belligerence=belligerenc+e
# bellow=bell+ow
# bellows=bellow+s
# bells=bell+s
# bellwethers=bellwether+s
# belly=bell+y
# bellyfull=bellyful+l
# belonging=belong+ing
# belongings=belonging+s
# belt=bel+t
# belting=belt+ing
# belts=belt+s
# bench=benc+h
# benches=benche+s
# benchmarks=benchmark+s
# bend=ben+d
# bending=bend+ing
# bends=bend+s
# benediction=benedictio+n
# benefactor=benefacto+r
# beneficence=beneficenc+e
# beneficiaries=beneficiarie+s
# beneficiary=beneficiar+y
# benefit=benefi+t
# benefits=benefit+s
# benevolence=benevolenc+e
# bent=ben+t
# benzene=benzen+e
# bequest=beques+t
# bequests=bequest+s
# bereavement=bereavemen+t
# bereavements=bereavement+s
# bergs=berg+s
# beriberi=beriber+i
# berries=berrie+s
# berry=berr+y
# berth=bert+h
# beryllium=berylliu+m
# besiegers=besieger+s
# bestes=beste+s
# bestowal=bestowa+l
# bestseller=bestsell+er
# betrayal=betraya+l
# betrayer=betray+er
# betrothal=betrotha+l
# bets=bet+s
# betterment=bettermen+t
# betties=bettie+s
# betting=bett+ing
# beveling=bevel+ing
# bevels=bevel+s
# beverage=beverag+e
# beverages=beverage+s
# bevy=bev+y
# bewilderment=bewildermen+t
# bhoy=bho+y
# bias=bia+s
# biases=biase+s
# bibles=bible+s
# bibliographies=bibliographie+s
# bibliography=bibliograph+y
# bibliophiles=bibliophile+s
# bicarbonate=bicarbonat+e
# bicep=bice+p
# biceps=bicep+s
# bich=bic+h
# biches=biche+s
# bickering=bicker+ing
# bicycle=bicycl+e
# bicycles=bicycle+s
# bidder=bidd+er
# bidders=bidder+s
# biddies=biddie+s
# bidding=bidd+ing
# bids=bid+s
# biennium=bienniu+m
# bifocals=bifocal+s
# bigotry=bigotr+y
# bigots=bigot+s
# bikinis=bikini+s
# bile=bil+e
# bilge=bilg+e
# bilharziasis=bilharziasi+s
# bill=bil+l
# billboard=billboar+d
# billboards=billboard+s
# billet=bille+t
# billets=billet+s
# billiard=billiar+d
# billing=bill+ing
# billions=billion+s
# billows=billow+s
# bills=bill+s
# bind=bin+d
# binder=bind+er
# binders=binder+s
# binding=bind+ing
# bindle=bindl+e
# binge=bing+e
# binoculars=binocular+s
# bins=bin+s
# biographer=biograph+er
# biographers=biographer+s
# biography=biograph+y
# biologist=biologis+t
# biologists=biologist+s
# biology=biolog+y
# biophysicist=biophysicis+t
# biopsies=biopsie+s
# biopsy=biops+y
# biplane=biplan+e
# birch=birc+h
# birches=birche+s
# bird=bir+d
# birdbath=birdbat+h
# birdie=birdi+e
# birdies=birdie+s
# birds=bird+s
# birefringence=birefringenc+e
# birth=birt+h
# birthcontrol=birthcontro+l
# birthday=birthda+y
# birthplace=birthplac+e
# birthright=birthrigh+t
# births=birth+s
# biscuit=biscui+t
# biscuits=biscuit+s
# bishop=bisho+p
# bishopry=bishopr+y
# bishops=bishop+s
# bison=biso+n
# bisque=bisqu+e
# bitch=bitc+h
# bite=bit+e
# biter=bit+er
# bites=bite+s
# bits=bit+s
# bitterness=bitternes+s
# bitters=bitter+s
# bivouac=bivoua+c
# black=blac+k
# blackberry=blackberr+y
# blackbirds=blackbird+s
# blackboard=blackboar+d
# blackening=blacken+ing
# blacking=black+ing
# blackjack=blackjac+k
# blackmail=blackmai+l
# blackmailer=blackmail+er
# blackness=blacknes+s
# blackout=blackou+t
# blacks=black+s
# blacksmith=blacksmit+h
# blade=blad+e
# blades=blade+s
# blame=blam+e
# blandness=blandnes+s
# blank=blan+k
# blanket=blanke+t
# blankets=blanket+s
# blanks=blank+s
# blasphemies=blasphemie+s
# blasphemy=blasphem+y
# blast=blas+t
# blastdown=blastdow+n
# blasts=blast+s
# blatancy=blatanc+y
# blaze=blaz+e
# blazer=blaz+er
# bleachers=bleacher+s
# bleat=blea+t
# bleats=bleat+s
# blebs=bleb+s
# bleeding=bleed+ing
# bleedings=bleeding+s
# bleeps=bleep+s
# blemish=blemis+h
# blemishes=blemishe+s
# blend=blen+d
# blends=blend+s
# blessing=bless+ing
# blessings=blessing+s
# blight=bligh+t
# blind=blin+d
# blindness=blindnes+s
# blinds=blind+s
# blinkers=blinker+s
# blips=blip+s
# bliss=blis+s
# blister=blist+er
# blisters=blister+s
# blitz=blit+z
# blitzes=blitze+s
# blizzard=blizzar+d
# blizzards=blizzard+s
# bloat=bloa+t
# blob=blo+b
# bloc=blo+c
# block=bloc+k
# blockade=blockad+e
# blockages=blockage+s
# blockhouse=blockhous+e
# blocks=block+s
# bloke=blok+e
# blokes=bloke+s
# blonde=blond+e
# blondes=blonde+s
# blood=bloo+d
# bloodhounds=bloodhound+s
# bloodlust=bloodlus+t
# bloodroot=bloodroo+t
# bloods=blood+s
# bloodshed=bloodshe+d
# bloodspots=bloodspot+s
# bloodstains=bloodstain+s
# bloodstream=bloodstrea+m
# bloom=bloo+m
# blooming=bloom+ing
# blooms=bloom+s
# bloops=bloop+s
# blossom=blosso+m
# blossoms=blossom+s
# blot=blo+t
# blots=blot+s
# blouse=blous+e
# blouses=blouse+s
# blower=blow+er
# blowers=blower+s
# blowfish=blowfis+h
# blowing=blow+ing
# blows=blow+s
# blowup=blowu+p
# blubber=blubb+er
# bludgeon=bludgeo+n
# blue=blu+e
# blueberries=blueberrie+s
# blueberry=blueberr+y
# bluebonnets=bluebonnet+s
# bluebook=blueboo+k
# bluebush=bluebus+h
# bluefish=bluefis+h
# blueprint=blueprin+t
# blueprints=blueprint+s
# blues=blue+s
# bluestocking=bluestock+ing
# bluff=bluf+f
# bluffs=bluff+s
# bluing=blu+ing
# blunder=blund+er
# blunderings=blundering+s
# blunders=blunder+s
# bluntness=bluntnes+s
# blur=blu+r
# blushes=blushe+s
# bluster=blust+er
# bmews=bmew+s
# boar=boa+r
# board=boar+d
# boarder=board+er
# boarding=board+ing
# boardinghouses=boardinghouse+s
# boards=board+s
# boast=boas+t
# boastings=boasting+s
# boat=boa+t
# boatel=boate+l
# boatels=boatel+s
# boaters=boater+s
# boathouses=boathouse+s
# boating=boat+ing
# boatload=boatloa+d
# boatloads=boatload+s
# boatman=boatma+n
# boatmen=boatme+n
# boats=boat+s
# boatsmen=boatsme+n
# boatswain=boatswai+n
# boatyards=boatyard+s
# bobbins=bobbin+s
# bobby=bobb+y
# bod's=bod'+s
# bod/day=bod/da+y
# bod/day/1,000=bod/day/1,00+0
# bod/day/acre=bod/day/acr+e
# bodice=bodic+e
# bodies=bodie+s
# body=bod+y
# bodybuilder=bodybuild+er
# bodybuilders=bodybuilder+s
# bodybuilding=bodybuild+ing
# bodyguard=bodyguar+d
# bodyweight=bodyweigh+t
# bogey=boge+y
# bogeymen=bogeyme+n
# bogeys=bogey+s
# bogies=bogie+s
# bogy=bog+y
# boies=boie+s
# boil=boi+l
# boiler=boil+er
# boilers=boiler+s
# boils=boil+s
# boldness=boldnes+s
# bolo=bol+o
# bologna=bologn+a
# bolster=bolst+er
# bolt=bol+t
# bolts=bolt+s
# bomb=bom+b
# bombardment=bombardmen+t
# bomber=bomb+er
# bombers=bomber+s
# bombing=bomb+ing
# bombings=bombing+s
# bombs=bomb+s
# bombus=bombu+s
# bonanza=bonanz+a
# bond=bon+d
# bondage=bondag+e
# bonds=bond+s
# bondsman=bondsma+n
# bone=bon+e
# bones=bone+s
# bonfire=bonfir+e
# bonfires=bonfire+s
# bongo=bong+o
# bonnet=bonne+t
# bonus=bonu+s
# bonzes=bonze+s
# booboo=boobo+o
# booby=boob+y
# boogie=boogi+e
# book=boo+k
# bookcase=bookcas+e
# bookcases=bookcase+s
# booker=book+er
# bookers=booker+s
# bookies=bookie+s
# booking=book+ing
# bookings=booking+s
# bookkeeping=bookkeep+ing
# booklet=bookle+t
# booklets=booklet+s
# booklists=booklist+s
# books=book+s
# bookseller=booksell+er
# bookshelf=bookshel+f
# bookshelves=bookshelve+s
# boom=boo+m
# boomerang=boomeran+g
# boomtown=boomtow+n
# boon=boo+n
# boors=boor+s
# boos=boo+s
# boost=boos+t
# booster=boost+er
# boosts=boost+s
# boot=boo+t
# booth=boot+h
# booths=booth+s
# bootlegger=bootlegg+er
# bootleggers=bootlegger+s
# boots=boot+s
# booty=boot+y
# booze=booz+e
# borates=borate+s
# borax=bora+x
# border=bord+er
# borderlands=borderland+s
# borderline=borderlin+e
# borders=border+s
# bore=bor+e
# boredom=boredo+m
# borer=bor+er
# bores=bore+s
# boring=bor+ing
# borough=boroug+h
# boroughs=borough+s
# borrower=borrow+er
# borrowing=borrow+ing
# bosom=boso+m
# bosoms=bosom+s
# boss=bos+s
# bosses=bosse+s
# bossman=bossma+n
# botanists=botanist+s
# botany=botan+y
# bottle=bottl+e
# bottleneck=bottlenec+k
# bottlenecks=bottleneck+s
# bottles=bottle+s
# bottom=botto+m
# bottoms=bottom+s
# boucle=boucl+e
# bough=boug+h
# boughs=bough+s
# boulder=bould+er
# boulders=boulder+s
# boulevard=boulevar+d
# boulevards=boulevard+s
# bounce=bounc+e
# bouncing=bounc+ing
# bound=boun+d
# boundaries=boundarie+s
# boundary=boundar+y
# bounds=bound+s
# bounty=bount+y
# bouquet=bouque+t
# bouquets=bouquet+s
# bourbon=bourbo+n
# bourgeois=bourgeoi+s
# bourgeoisie=bourgeoisi+e
# bout=bou+t
# bouts=bout+s
# bovine=bovin+e
# bovines=bovine+s
# bowels=bowel+s
# bower=bow+er
# bowing=bow+ing
# bowl=bow+l
# bowls=bowl+s
# bows=bow+s
# bowstring=bowstr+ing
# boxcar=boxca+r
# boxcars=boxcar+s
# boxer=box+er
# boxes=boxe+s
# boyars=boyar+s
# boycott=boycot+t
# boyhood=boyhoo+d
# boys=boy+s
# brace=brac+e
# bracelet=bracele+t
# braces=brace+s
# bracing=brac+ing
# bracket=bracke+t
# brackets=bracket+s
# brad=bra+d
# brag=bra+g
# braggadocio=braggadoci+o
# braids=braid+s
# brain=brai+n
# brains=brain+s
# brainwashing=brainwash+ing
# brake=brak+e
# brakes=brake+s
# brambles=bramble+s
# bran=bra+n
# branch=branc+h
# branches=branche+s
# brand=bran+d
# brands=brand+s
# brandy=brand+y
# brashness=brashnes+s
# brass=bras+s
# brassiere=brassier+e
# bravado=bravad+o
# bravery=braver+y
# bravura=bravur+a
# brawl=braw+l
# brawle=brawl+e
# brazenness=brazennes+s
# brazier=brazi+er
# brazil=brazi+l
# breach=breac+h
# bread=brea+d
# breadth=breadt+h
# break=brea+k
# breakables=breakable+s
# breakage=breakag+e
# breakaway=breakawa+y
# breakdown=breakdow+n
# breakdowns=breakdown+s
# breaker=break+er
# breakers=breaker+s
# breakfast=breakfas+t
# breakfasts=breakfast+s
# breaking=break+ing
# breakoff=breakof+f
# breaks=break+s
# breakthrough=breakthroug+h
# breakthroughs=breakthrough+s
# breakup=breaku+p
# breakups=breakup+s
# breakwater=breakwat+er
# breakwaters=breakwater+s
# breast=breas+t
# breasts=breast+s
# breastworks=breastwork+s
# breath=breat+h
# breather=breath+er
# breathing=breath+ing
# breaths=breath+s
# breeches=breeche+s
# breed=bree+d
# breeds=breed+s
# breeze=breez+e
# breezes=breeze+s
# brethren=brethre+n
# brevity=brevit+y
# brew=bre+w
# brewers=brewer+s
# brewery=brewer+y
# bribers=briber+s
# bribes=bribe+s
# brick=bric+k
# bricklayers=bricklayer+s
# bricklaying=bricklay+ing
# bricks=brick+s
# bridal=brida+l
# bride=brid+e
# bridegroom=bridegroo+m
# brides=bride+s
# bridesmaids=bridesmaid+s
# bridge=bridg+e
# bridgehead=bridgehea+d
# bridges=bridge+s
# bridgework=bridgewor+k
# bridle=bridl+e
# brief=brie+f
# briefcase=briefcas+e
# briefing=brief+ing
# briefs=brief+s
# brig=bri+g
# brigade=brigad+e
# brigades=brigade+s
# brigadier=brigadi+er
# brightness=brightnes+s
# brilliance=brillianc+e
# brim=bri+m
# brindle=brindl+e
# bringing=bring+ing
# brink=brin+k
# brinkmanship=brinkmanshi+p
# briskness=brisknes+s
# bristle=bristl+e
# bristles=bristle+s
# broadcast=broadcas+t
# broadcasting=broadcast+ing
# broadcastings=broadcasting+s
# broadcasts=broadcast+s
# broadening=broaden+ing
# broadside=broadsid+e
# brocade=brocad+e
# broccoli=broccol+i
# brochure=brochur+e
# brochures=brochure+s
# brockle=brockl+e
# broil=broi+l
# broiler=broil+er
# broker=brok+er
# brokerage=brokerag+e
# brokers=broker+s
# bromides=bromide+s
# bromphenol=brompheno+l
# bronc=bron+c
# bronchi=bronch+i
# bronchiole=bronchiol+e
# bronchioles=bronchiole+s
# bronchiolitis=bronchioliti+s
# bronchus=bronchu+s
# broncs=bronc+s
# bronze=bronz+e
# brood=broo+d
# broods=brood+s
# brook=broo+k
# broom=broo+m
# broth=brot+h
# brothel=brothe+l
# brothels=brothel+s
# brother=broth+er
# brotherhood=brotherhoo+d
# brothers=brother+s
# brown=brow+n
# brows=brow+s
# brucellosis=brucellosi+s
# bruise=bruis+e
# bruises=bruise+s
# brunches=brunche+s
# brunettes=brunette+s
# brunt=brun+t
# brush=brus+h
# brushcut=brushcu+t
# brushes=brushe+s
# brushfire=brushfir+e
# brushing=brush+ing
# brushwork=brushwor+k
# brutalities=brutalitie+s
# brutality=brutalit+y
# brute=brut+e
# btu's=btu'+s
# bubble=bubbl+e
# bubbles=bubble+s
# buck=buc+k
# buckaroos=buckaroo+s
# buckboard=buckboar+d
# bucket=bucke+t
# buckets=bucket+s
# buckle=buckl+e
# buckles=buckle+s
# bucks=buck+s
# buckshot=bucksho+t
# buckskin=buckski+n
# buckskins=buckskin+s
# buckwheat=buckwhea+t
# buddies=buddie+s
# buddy=budd+y
# budget=budge+t
# budgeting=budget+ing
# budgets=budget+s
# buds=bud+s
# buff=buf+f
# buffalo=buffal+o
# buffaloes=buffaloe+s
# buffer=buff+er
# buffet=buffe+t
# buffetings=buffeting+s
# buffets=buffet+s
# buffoon=buffoo+n
# buffoons=buffoon+s
# buffs=buff+s
# buggers=bugger+s
# buggies=buggie+s
# buggy=bugg+y
# bugle=bugl+e
# bugler=bugl+er
# bugs=bug+s
# build=buil+d
# builder=build+er
# builders=builder+s
# building=build+ing
# buildings=building+s
# buildup=buildu+p
# bulb=bul+b
# bulbs=bulb+s
# bulge=bulg+e
# bulk=bul+k
# bulkhead=bulkhea+d
# bulkheads=bulkhead+s
# bull=bul+l
# bullet=bulle+t
# bulletin=bulleti+n
# bulletins=bulletin+s
# bullets=bullet+s
# bullhide=bullhid+e
# bullies=bullie+s
# bulls=bull+s
# bullshit=bullshi+t
# bullwhackers=bullwhacker+s
# bully=bull+y
# bullyboys=bullyboy+s
# bulwark=bulwar+k
# bumblebee=bumblebe+e
# bumblebees=bumblebee+s
# bumming=bumm+ing
# bump=bum+p
# bumper=bump+er
# bumpers=bumper+s
# bumps=bump+s
# bums=bum+s
# bunch=bunc+h
# bundle=bundl+e
# bundles=bundle+s
# bungalow=bungal+ow
# bunk=bun+k
# bunker=bunk+er
# bunkmate=bunkmat+e
# bunkmates=bunkmate+s
# bunks=bunk+s
# buns=bun+s
# bunt=bun+t
# bunter=bunt+er
# bunters=bunter+s
# buoyancy=buoyanc+y
# buoys=buoy+s
# burden=burde+n
# burdens=burden+s
# bureau=burea+u
# bureaucracies=bureaucracie+s
# bureaucracy=bureaucrac+y
# bureaucrat=bureaucra+t
# bureaucratization=bureaucratizatio+n
# bureaucrats=bureaucrat+s
# bureaus=bureau+s
# burgesses=burgesse+s
# burglar=burgla+r
# burglars=burglar+s
# burglary=burglar+y
# burial=buria+l
# burl=bur+l
# burlesque=burlesqu+e
# burlesques=burlesque+s
# burley=burle+y
# burn=bur+n
# burners=burner+s
# burning=burn+ing
# burnings=burning+s
# burns=burn+s
# burr=bur+r
# burrow=burr+ow
# burrows=burrow+s
# burrs=burr+s
# bursitis=bursiti+s
# burst=burs+t
# bursts=burst+s
# busboy=busbo+y
# buses=buse+s
# bush=bus+h
# bushel=bushe+l
# bushels=bushel+s
# bushes=bushe+s
# business=busines+s
# businesses=businesse+s
# businessman=businessma+n
# businessmen=businessme+n
# buss=bus+s
# busses=busse+s
# bust=bus+t
# bustle=bustl+e
# busts=bust+s
# busyness=busynes+s
# butane=butan+e
# butcher=butch+er
# butchery=butcher+y
# butler=butl+er
# butlers=butler+s
# butt=but+t
# butter=butt+er
# butterfat=butterfa+t
# butterflies=butterflie+s
# butterfly=butterfl+y
# butternut=butternu+t
# buttocks=buttock+s
# button=butto+n
# buttonholes=buttonhole+s
# buttons=button+s
# buttresses=buttresse+s
# butts=butt+s
# butyrate=butyrat+e
# buyer=buy+er
# buyers=buyer+s
# buying=buy+ing
# buzz=buz+z
# buzzes=buzze+s
# byinge=bying+e
# byline=bylin+e
# bypass=bypas+s
# byproduct=byproduc+t
# byproducts=byproduct+s
# bystander=bystand+er
# byword=bywor+d
# cabana=caban+a
# cabanas=cabana+s
# cabaret=cabare+t
# cabbage=cabbag+e
# cabdriver=cabdriv+er
# cabin=cabi+n
# cabinet=cabine+t
# cabinetmakers=cabinetmaker+s
# cabinets=cabinet+s
# cabins=cabin+s
# cable=cabl+e
# cables=cable+s
# cabs=cab+s
# cacao=caca+o
# cache=cach+e
# cacophonist=cacophonis+t
# cacophony=cacophon+y
# cadaver=cadav+er
# cadence=cadenc+e
# cadenza=cadenz+a
# cadet=cade+t
# cadmium=cadmiu+m
# cadre=cadr+e
# cafe=caf+e
# cafes=cafe+s
# cafeteria=cafeteri+a
# cafeterias=cafeteria+s
# cage=cag+e
# cages=cage+s
# cahoots=cahoot+s
# cake=cak+e
# cakes=cake+s
# calamities=calamitie+s
# calamity=calamit+y
# calcification=calcificatio+n
# calcium=calciu+m
# calculation=calculatio+n
# calculations=calculation+s
# calculators=calculator+s
# calculi=calcul+i
# calendar=calenda+r
# calendars=calendar+s
# calf=cal+f
# calfskin=calfski+n
# caliber=calib+er
# calibers=caliber+s
# calibration=calibratio+n
# calibrations=calibration+s
# calibre=calibr+e
# calico=calic+o
# calinda=calind+a
# caliper=calip+er
# calipers=caliper+s
# caliphs=caliph+s
# calisthenics=calisthenic+s
# call=cal+l
# caller=call+er
# callers=caller+s
# calligraphers=calligrapher+s
# calligraphy=calligraph+y
# calling=call+ing
# callousness=callousnes+s
# calls=call+s
# calluses=calluse+s
# calm=cal+m
# calmness=calmnes+s
# calorie=calori+e
# calories=calorie+s
# calorimeter=calorimet+er
# calumny=calumn+y
# calves=calve+s
# calypso=calyps+o
# camaraderie=camaraderi+e
# camel=came+l
# camellias=camellia+s
# camels=camel+s
# cameos=cameo+s
# camera=camer+a
# cameramen=camerame+n
# cameras=camera+s
# camouflage=camouflag+e
# camp=cam+p
# campaign=campaig+n
# campaigners=campaigner+s
# campaigning=campaign+ing
# campaigns=campaign+s
# camper=camp+er
# campers=camper+s
# campfire=campfir+e
# campground=campgroun+d
# campgrounds=campground+s
# campmate=campmat+e
# camps=camp+s
# campsites=campsite+s
# campus=campu+s
# campuses=campuse+s
# cams=cam+s
# canals=canal+s
# cancellation=cancellatio+n
# cancer=canc+er
# cancers=cancer+s
# candidacy=candidac+y
# candidate=candidat+e
# candidates=candidate+s
# candies=candie+s
# candle=candl+e
# candles=candle+s
# candlewick=candlewic+k
# candor=cando+r
# candour=candou+r
# candy=cand+y
# cane=can+e
# canine=canin+e
# canister=canist+er
# canisters=canister+s
# canker=cank+er
# cannery=canner+y
# cannibals=cannibal+s
# cannon=canno+n
# cannonball=cannonbal+l
# canoe=cano+e
# canoes=canoe+s
# canon=cano+n
# canons=canon+s
# canopy=canop+y
# cans=can+s
# cant=can+t
# cantaloupe=cantaloup+e
# canteen=cantee+n
# canter=cant+er
# cantilevers=cantilever+s
# cantles=cantle+s
# cantonment=cantonmen+t
# canvas=canva+s
# canvases=canvase+s
# canvass=canvas+s
# canvassers=canvasser+s
# canvassing=canvass+ing
# canyon=canyo+n
# canyons=canyon+s
# canyonside=canyonsid+e
# cap'n=cap'+n
# capabilities=capabilitie+s
# capability=capabilit+y
# capacitance=capacitanc+e
# capacities=capacitie+s
# capacitor=capacito+r
# capacitors=capacitor+s
# capacity=capacit+y
# cape=cap+e
# caper=cap+er
# capercailzie=capercailzi+e
# capers=caper+s
# capes=cape+s
# capillary=capillar+y
# capita=capit+a
# capital=capita+l
# capitalism=capitalis+m
# capitalist=capitalis+t
# capitalists=capitalist+s
# capitals=capital+s
# capitol=capito+l
# capitulation=capitulatio+n
# caps=cap+s
# capsicum=capsicu+m
# ...
# unbalance=unbalanc+e
# uncertainties=uncertaintie+s
# uncertainty=uncertaint+y
# uncircumcision=uncircumcisio+n
# uncle=uncl+e
# uncles=uncle+s
# unconcern=unconcer+n
# unconscious=unconsciou+s
# unconvincing=unconvinc+ing
# unction=unctio+n
# underachievers=underachiever+s
# underarm=underar+m
# underbedding=underbedd+ing
# underbelly=underbell+y
# underbracing=underbrac+ing
# underbrush=underbrus+h
# underclassman=underclassma+n
# underclothes=underclothe+s
# undercurrent=undercurren+t
# undercut=undercu+t
# underdog=underdo+g
# undergirding=undergird+ing
# undergraduate=undergraduat+e
# undergraduates=undergraduate+s
# underground=undergroun+d
# undergrowth=undergrowt+h
# underhandedness=underhandednes+s
# underling=underl+ing
# underpinning=underpinn+ing
# undershirt=undershir+t
# underside=undersid+e
# understanding=understand+ing
# understandings=understanding+s
# understatement=understatemen+t
# understructure=understructur+e
# undertaker=undertak+er
# undertaking=undertak+ing
# undertakings=undertaking+s
# undertow=undert+ow
# underwear=underwea+r
# underworld=underworl+d
# underwriter=underwrit+er
# underwriters=underwriter+s
# underwriting=underwrit+ing
# undoing=undo+ing
# unease=uneas+e
# uneasiness=uneasines+s
# unemployment=unemploymen+t
# unfoldment=unfoldmen+t
# unfortunate=unfortunat+e
# unfortunates=unfortunate+s
# unfrocking=unfrock+ing
# unhappiness=unhappines+s
# unification=unificatio+n
# unifications=unification+s
# uniform=unifor+m
# uniformity=uniformit+y
# uniforms=uniform+s
# uninitiate=uninitiat+e
# union=unio+n
# unions=union+s
# uniqueness=uniquenes+s
# unison=uniso+n
# unit=uni+t
# unities=unitie+s
# units=unit+s
# unity=unit+y
# universality=universalit+y
# universals=universal+s
# universe=univers+e
# universities=universitie+s
# university=universit+y
# unknown=unknow+n
# unknowns=unknown+s
# unnaturalness=unnaturalnes+s
# unoriginals=unoriginal+s
# unpleasantness=unpleasantnes+s
# unpredictability=unpredictabilit+y
# unrealism=unrealis+m
# unreality=unrealit+y
# unreason=unreaso+n
# unreliability=unreliabilit+y
# unrest=unres+t
# unselfconsciousness=unselfconsciousnes+s
# untidiness=untidines+s
# untrustworthiness=untrustworthines+s
# untruth=untrut+h
# unwillingness=unwillingnes+s
# upbringing=upbring+ing
# upgrading=upgrad+ing
# upheaval=upheava+l
# upholders=upholder+s
# upholstery=upholster+y
# upkeep=upkee+p
# uplands=upland+s
# uplift=uplif+t
# upperclassmen=upperclassme+n
# uppercut=uppercu+t
# upright=uprigh+t
# uprisings=uprising+s
# uproar=uproa+r
# upset=upse+t
# upsets=upset+s
# upshot=upsho+t
# upshots=upshot+s
# upstairs=upstair+s
# upsurge=upsurg+e
# upswing=upsw+ing
# uptake=uptak+e
# uptown=uptow+n
# uptrend=uptren+d
# upturn=uptur+n
# uranium=uraniu+m
# uranyl=urany+l
# urbanism=urbanis+m
# urbanization=urbanizatio+n
# urea=ure+a
# uremia=uremi+a
# urethane=urethan+e
# urethanes=urethane+s
# urethra=urethr+a
# urge=urg+e
# urgencies=urgencie+s
# urgency=urgenc+y
# urges=urge+s
# urgings=urging+s
# urinals=urinal+s
# urine=urin+e
# urns=urn+s
# usage=usag+e
# usages=usage+s
# usefulness=usefulnes+s
# uselessness=uselessnes+s
# users=user+s
# uses=use+s
# usga=usg+a
# usher=ush+er
# usis=usi+s
# usom=uso+m
# ussr=uss+r
# utensils=utensil+s
# utilities=utilitie+s
# utility=utilit+y
# utilization=utilizatio+n
# utmost=utmos+t
# utopia=utopi+a
# utopian=utopia+n
# utopianism=utopianis+m
# utopians=utopian+s
# utopias=utopia+s
# utterance=utteranc+e
# utterances=utterance+s
# uttermost=uttermos+t
# vacancies=vacancie+s
# vacancy=vacanc+y
# vacation=vacatio+n
# vacationers=vacationer+s
# vacationland=vacationlan+d
# vacations=vacation+s
# vaccination=vaccinatio+n
# vaccine=vaccin+e
# vacuolization=vacuolizatio+n
# vacuum=vacuu+m
# vagabond=vagabon+d
# vagaries=vagarie+s
# vagina=vagin+a
# vaginal=vagina+l
# vagueness=vaguenes+s
# valet=vale+t
# valewe=valew+e
# validation=validatio+n
# validity=validit+y
# valley=valle+y
# valleys=valley+s
# valor=valo+r
# valuation=valuatio+n
# valuations=valuation+s
# value=valu+e
# values=value+s
# valve=valv+e
# valves=valve+s
# vampires=vampire+s
# vandalism=vandalis+m
# vandals=vandal+s
# vanguard=vanguar+d
# vanilla=vanill+a
# vanities=vanitie+s
# vanity=vanit+y
# vantage=vantag+e
# vapor=vapo+r
# vaporization=vaporizatio+n
# vaquero=vaquer+o
# var.=var+.
# variability=variabilit+y
# variable=variabl+e
# variables=variable+s
# variance=varianc+e
# variant=varian+t
# variation=variatio+n
# variations=variation+s
# varieties=varietie+s
# variety=variet+y
# varmint=varmin+t
# varnish=varnis+h
# varnishes=varnishe+s
# vasa=vas+a
# vase=vas+e
# vases=vase+s
# vasorum=vasoru+m
# vassal=vassa+l
# vaudeville=vaudevill+e
# vault=vaul+t
# vaulting=vault+ing
# vaults=vault+s
# veal=vea+l
# vector=vecto+r
# vectors=vector+s
# vegetable=vegetabl+e
# vegetables=vegetable+s
# vegetarian=vegetaria+n
# vegetation=vegetatio+n
# vehemence=vehemenc+e
# vehicle=vehicl+e
# vehicles=vehicle+s
# veil=vei+l
# veils=veil+s
# vein=vei+n
# veins=vein+s
# veldt=veld+t
# vellum=vellu+m
# velocities=velocitie+s
# velocity=velocit+y
# velour=velou+r
# velours=velour+s
# velvet=velve+t
# vendor=vendo+r
# vendors=vendor+s
# veneer=vene+er
# veneration=veneratio+n
# vengeance=vengeanc+e
# venison=veniso+n
# venom=veno+m
# vent=ven+t
# ventilation=ventilatio+n
# ventilator=ventilato+r
# ventricle=ventricl+e
# ventricles=ventricle+s
# vents=vent+s
# venture=ventur+e
# ventures=venture+s
# veracity=veracit+y
# veranda=verand+a
# verandah=veranda+h
# verandas=veranda+s
# verb=ver+b
# verbenas=verbena+s
# verbs=verb+s
# verdict=verdic+t
# verge=verg+e
# verification=verificatio+n
# verisimilitude=verisimilitud+e
# verity=verit+y
# vermilion=vermilio+n
# vermouth=vermout+h
# vernacular=vernacula+r
# vernier=verni+er
# veronica=veronic+a
# versatility=versatilit+y
# verse=vers+e
# verses=verse+s
# version=versio+n
# versions=version+s
# vertebrae=vertebra+e
# vertebrate=vertebrat+e
# vertebrates=vertebrate+s
# vertex=verte+x
# vertigo=vertig+o
# verve=verv+e
# vessel=vesse+l
# vessels=vessel+s
# vest=ves+t
# vestibule=vestibul+e
# vestige=vestig+e
# vestments=vestment+s
# vests=vest+s
# veteran=vetera+n
# veterans=veteran+s
# veterinarian=veterinaria+n
# veterinarians=veterinarian+s
# veto=vet+o
# viability=viabilit+y
# vibes=vibe+s
# vibrancy=vibranc+y
# vibration=vibratio+n
# vibrato=vibrat+o
# vicar=vica+r
# vice=vic+e
# vices=vice+s
# vicinity=vicinit+y
# viciousness=viciousnes+s
# vicissitudes=vicissitude+s
# victim=victi+m
# victims=victim+s
# victor=victo+r
# victories=victorie+s
# victory=victor+y
# victuals=victual+s
# video=vide+o
# view=vie+w
# viewer=view+er
# viewers=viewer+s
# viewpoint=viewpoin+t
# viewpoints=viewpoint+s
# views=view+s
# vigil=vigi+l
# vigilance=vigilanc+e
# vigilantism=vigilantis+m
# vignette=vignett+e
# vigor=vigo+r
# villa=vill+a
# village=villag+e
# villager=villag+er
# villagers=villager+s
# villages=village+s
# villain=villai+n
# villains=villain+s
# vindication=vindicatio+n
# vine=vin+e
# vinegar=vinega+r
# vines=vine+s
# vineyard=vineyar+d
# vineyards=vineyard+s
# vintage=vintag+e
# vintner=vintn+er
# vinyl=viny+l
# vioiln=vioil+n
# violation=violatio+n
# violations=violation+s
# violence=violenc+e
# violet=viole+t
# violets=violet+s
# violin=violi+n
# violinist=violinis+t
# violinists=violinist+s
# violins=violin+s
# virgin=virgi+n
# virginity=virginit+y
# virility=virilit+y
# virtue=virtu+e
# virtues=virtue+s
# virtuosity=virtuosit+y
# virtuoso=virtuos+o
# virulence=virulenc+e
# virus=viru+s
# visa=vis+a
# visage=visag+e
# viscera=viscer+a
# viscoelasticity=viscoelasticit+y
# viscometer=viscomet+er
# viscosity=viscosit+y
# vise=vis+e
# visibility=visibilit+y
# vision=visio+n
# visions=vision+s
# visit=visi+t
# visitations=visitation+s
# visitor=visito+r
# visitors=visitor+s
# visits=visit+s
# vista=vist+a
# vistas=vista+s
# visualization=visualizatio+n
# vitality=vitalit+y
# vitals=vital+s
# vitamin=vitami+n
# vitamins=vitamin+s
# vitriol=vitrio+l
# vitro=vitr+o
# vivacity=vivacit+y
# vividness=vividnes+s
# vivo=viv+o
# vocabularies=vocabularie+s
# vocabulary=vocabular+y
# vocalism=vocalis+m
# vocalist=vocalis+t
# vocalists=vocalist+s
# vocalization=vocalizatio+n
# vocals=vocal+s
# vocation=vocatio+n
# vocational=vocationa+l
# vociferousness=vociferousnes+s
# vogue=vogu+e
# voice=voic+e
# voices=voice+s
# void=voi+d
# volatilization=volatilizatio+n
# volcano=volcan+o
# volcanos=volcano+s
# volition=volitio+n
# volley=volle+y
# volleyball=volleybal+l
# voltage=voltag+e
# voltages=voltage+s
# voltmeter=voltmet+er
# volts=volt+s
# volume=volum+e
# volumes=volume+s
# volunteer=volunte+er
# volunteers=volunteer+s
# vomica=vomic+a
# voodoo=voodo+o
# vortex=vorte+x
# vote=vot+e
# voter=vot+er
# voters=voter+s
# votes=vote+s
# voting=vot+ing
# vouchers=voucher+s
# voume=voum+e
# vowel=vowe+l
# vowels=vowel+s
# vows=vow+s
# voyage=voyag+e
# voyager=voyag+er
# voyages=voyage+s
# vtol=vto+l
# vuhranduh=vuhrandu+h
# vulnerability=vulnerabilit+y
# vulture=vultur+e
# wads=wad+s
# waffles=waffle+s
# wage=wag+e
# wager=wag+er
# wages=wage+s
# wagon=wago+n
# wagons=wagon+s
# wahtahm=wahtah+m
# wail=wai+l
# wails=wail+s
# waist=wais+t
# waistcoat=waistcoa+t
# wait=wai+t
# waiter=wait+er
# waiters=waiter+s
# waiting=wait+ing
# waitress=waitres+s
# waitresses=waitresse+s
# wake=wak+e
# wakefulness=wakefulnes+s
# wales=wale+s
# walk=wal+k
# walker=walk+er
# walkout=walkou+t
# walkover=walkov+er
# walks=walk+s
# walkways=walkway+s
# wall=wal+l
# wallboard=wallboar+d
# wallet=walle+t
# wallop=wallo+p
# wallpaper=wallpap+er
# wallpapers=wallpaper+s
# walls=wall+s
# walnut=walnu+t
# walnuts=walnut+s
# walrus=walru+s
# waltz=walt+z
# wand=wan+d
# wanderer=wander+er
# wanderers=wanderer+s
# wandering=wander+ing
# wanderings=wandering+s
# want=wan+t
# wants=want+s
# ward=war+d
# warden=warde+n
# wardens=warden+s
# wardrobe=wardrob+e
# wardroom=wardroo+m
# wards=ward+s
# ware=war+e
# warehouse=warehous+e
# warehouses=warehouse+s
# wares=ware+s
# warfare=warfar+e
# warfront=warfron+t
# warhead=warhea+d
# warmth=warmt+h
# warmup=warmu+p
# warning=warn+ing
# warnings=warning+s
# warp=war+p
# warrant=warran+t
# warrants=warrant+s
# warranty=warrant+y
# warren=warre+n
# warrior=warrio+r
# warriors=warrior+s
# wars=war+s
# warships=warship+s
# wart=war+t
# wartime=wartim+e
# warts=wart+s
# warys=wary+s
# wash=was+h
# washbasin=washbasi+n
# washboard=washboar+d
# washbowl=washbow+l
# washer=wash+er
# washes=washe+s
# washing=wash+ing
# washings=washing+s
# wasp=was+p
# wastage=wastag+e
# waste=wast+e
# wastebasket=wastebaske+t
# wasteland=wastelan+d
# wastes=waste+s
# wastewater=wastewat+er
# wastrel=wastre+l
# watch=watc+h
# watchdog=watchdo+g
# watchers=watcher+s
# watches=watche+s
# watching=watch+ing
# watchings=watching+s
# watchmaker=watchmak+er
# watchmen=watchme+n
# water=wat+er
# watercolor=watercolo+r
# watercolorist=watercoloris+t
# watercolorists=watercolorist+s
# watercolors=watercolor+s
# waterfall=waterfal+l
# waterfalls=waterfall+s
# waterflows=waterflow+s
# waterfront=waterfron+t
# waterline=waterlin+e
# watermelon=watermelo+n
# waterproofing=waterproof+ing
# waters=water+s
# watershed=watershe+d
# watersheds=watershed+s
# waterside=watersid+e
# waterway=waterwa+y
# waterways=waterway+s
# watt=wat+t
# wattles=wattle+s
# wave=wav+e
# wavelength=wavelengt+h
# wavelengths=wavelength+s
# waver=wav+er
# wavers=waver+s
# waves=wave+s
# waving=wav+ing
# ways=way+s
# wayside=waysid+e
# wbai=wba+i
# weakening=weaken+ing
# weakness=weaknes+s
# weaknesses=weaknesse+s
# wealth=wealt+h
# weapon=weapo+n
# weaponry=weaponr+y
# weapons=weapon+s
# wear=wea+r
# weariness=wearines+s
# weasel=wease+l
# weather=weath+er
# weave=weav+e
# weaves=weave+s
# wedding=wedd+ing
# weddings=wedding+s
# wedge=wedg+e
# wedlock=wedloc+k
# weeds=weed+s
# week=wee+k
# weekday=weekda+y
# weekend=weeken+d
# weekends=weekend+s
# weeklies=weeklie+s
# weekly=weekl+y
# weeks=week+s
# weeping=weep+ing
# weight=weigh+t
# weighting=weight+ing
# weightlessness=weightlessnes+s
# weights=weight+s
# weir=wei+r
# weirdy=weird+y
# weirs=weir+s
# welcome=welcom+e
# welding=weld+ing
# welfare=welfar+e
# well=wel+l
# wellbeing=wellbe+ing
# wells=well+s
# welter=welt+er
# welts=welt+s
# wetlands=wetland+s
# wetness=wetnes+s
# wetting=wett+ing
# whack=whac+k
# wharf=whar+f
# wharves=wharve+s
# wheat=whea+t
# wheel=whee+l
# wheels=wheel+s
# wheezes=wheeze+s
# whereabouts=whereabout+s
# wherefores=wherefore+s
# whiff=whif+f
# while=whil+e
# whim=whi+m
# whims=whim+s
# whine=whin+e
# whinny=whinn+y
# whip=whi+p
# whiplash=whiplas+h
# whiplashes=whiplashe+s
# whips=whip+s
# whir=whi+r
# whirl=whir+l
# whirling=whirl+ing
# whirlwind=whirlwin+d
# whiskers=whisker+s
# whiskey=whiske+y
# whisky=whisk+y
# whisper=whisp+er
# whispering=whisper+ing
# whisperings=whispering+s
# whispers=whisper+s
# whistle=whistl+e
# whit=whi+t
# white=whit+e
# whiteface=whitefac+e
# whiteness=whitenes+s
# whites=white+s
# whitetail=whitetai+l
# whiz=whi+z
# whodunnit=whodunni+t
# whole=whol+e
# wholeness=wholenes+s
# wholes=whole+s
# wholesalers=wholesaler+s
# wholewheat=wholewhea+t
# whoop=whoo+p
# whoppers=whopper+s
# whore=whor+e
# whores=whore+s
# whorls=whorl+s
# whyfores=whyfore+s
# wick=wic+k
# wickedness=wickednes+s
# wicker=wick+er
# wicket=wicke+t
# wickets=wicket+s
# widegrip=widegri+p
# widow=wid+ow
# widower=widow+er
# widowhood=widowhoo+d
# widows=widow+s
# width=widt+h
# widths=width+s
# wielder=wield+er
# wieners=wiener+s
# wife=wif+e
# wiggle=wiggl+e
# wigmaker=wigmak+er
# wildcat=wildca+t
# wildcatter=wildcatt+er
# wilderness=wildernes+s
# wildlife=wildlif+e
# wildness=wildnes+s
# wiles=wile+s
# will=wil+l
# william=willia+m
# willingness=willingnes+s
# willow=will+ow
# wills=will+s
# wilt=wil+t
# winches=winche+s
# wind=win+d
# windbag=windba+g
# windbreaks=windbreak+s
# winder=wind+er
# winders=winder+s
# windfall=windfal+l
# windmill=windmil+l
# window=wind+ow
# windowpanes=windowpane+s
# windows=window+s
# winds=wind+s
# windshield=windshiel+d
# windstorm=windstor+m
# windup=windu+p
# wine=win+e
# winehead=winehea+d
# wines=wine+s
# wingback=wingbac+k
# wingman=wingma+n
# wings=wing+s
# wink=win+k
# winner=winn+er
# winners=winner+s
# winnings=winning+s
# winos=wino+s
# wins=win+s
# winter=wint+er
# winters=winter+s
# wintertime=wintertim+e
# wire=wir+e
# wires=wire+s
# wiring=wir+ing
# wisdom=wisdo+m
# wisenheimer=wisenheim+er
# wish=wis+h
# wishes=wishe+s
# wisp=wis+p
# wisps=wisp+s
# witch=witc+h
# witches=witche+s
# withdrawal=withdrawa+l
# withes=withe+s
# withholding=withhold+ing
# witness=witnes+s
# witnesses=witnesse+s
# wits=wit+s
# wives=wive+s
# wizard=wizar+d
# wlib=wli+b
# wohd=woh+d
# wolf=wol+f
# wolves=wolve+s
# woman=woma+n
# womanhood=womanhoo+d
# womb=wom+b
# women=wome+n
# wonder=wond+er
# wonderfulness=wonderfulnes+s
# wondering=wonder+ing
# wonders=wonder+s
# wood=woo+d
# woodcarver=woodcarv+er
# woodcutters=woodcutter+s
# woodgraining=woodgrain+ing
# woodland=woodlan+d
# woodpecker=woodpeck+er
# woods=wood+s
# woodshed=woodshe+d
# woodsmoke=woodsmok+e
# woodwind=woodwin+d
# woodwork=woodwor+k
# wool=woo+l
# woolen=woole+n
# woolworkers=woolworker+s
# woomera=woomer+a
# wooooosh=wooooos+h
# word=wor+d
# wording=word+ing
# words=word+s
# work=wor+k
# workbench=workbenc+h
# workday=workda+y
# worker=work+er
# workers=worker+s
# workingmen=workingme+n
# workings=working+s
# workman=workma+n
# workmanship=workmanshi+p
# workmen=workme+n
# workout=workou+t
# workouts=workout+s
# workpiece=workpiec+e
# works=work+s
# worksheet=workshee+t
# workshop=worksho+p
# workshops=workshop+s
# worktable=worktabl+e
# world=worl+d
# worlds=world+s
# worm=wor+m
# worms=worm+s
# worries=worrie+s
# worry=worr+y
# worship=worshi+p
# worshippers=worshipper+s
# worsted=worste+d
# worth=wort+h
# worthlessness=worthlessnes+s
# wound=woun+d
# wounds=wound+s
# wrack=wrac+k
# wrangler=wrangl+er
# wrapper=wrapp+er
# wrappers=wrapper+s
# wrapping=wrapp+ing
# wraps=wrap+s
# wrath=wrat+h
# wreath=wreat+h
# wreaths=wreath+s
# wreck=wrec+k
# wreckage=wreckag+e
# wrenches=wrenche+s
# wrestles=wrestle+s
# wrestlings=wrestling+s
# wretch=wretc+h
# wretchedness=wretchednes+s
# wrinkle=wrinkl+e
# wrinkles=wrinkle+s
# wrist=wris+t
# wrists=wrist+s
# wristwatch=wristwatc+h
# writ=wri+t
# writer=writ+er
# writers=writer+s
# writhing=writh+ing
# writing=writ+ing
# writings=writing+s
# writs=writ+s
# wrong=wron+g
# wrongdoer=wrongdo+er
# wrongdoing=wrongdo+ing
# wrongs=wrong+s
# wwrl=wwr+l
# xenon=xeno+n
# xenophobia=xenophobi+a
# xrelease=xreleas+e
# xreserve=xreserv+e
# xxxx=xxx+x
# xylem=xyle+m
# xylophones=xylophone+s
# yacht=yach+t
# yachtel=yachte+l
# yachtels=yachtel+s
# yachters=yachter+s
# yachts=yacht+s
# yachtsman=yachtsma+n
# yachtsmen=yachtsme+n
# yaks=yak+s
# yank=yan+k
# yard=yar+d
# yardage=yardag+e
# yards=yard+s
# yardstick=yardstic+k
# yarn=yar+n
# yarns=yarn+s
# yassuhs=yassuh+s
# yawl=yaw+l
# yawn=yaw+n
# yaws=yaw+s
# yeah=yea+h
# year=yea+r
# yearbook=yearboo+k
# yearning=yearn+ing
# yearnings=yearning+s
# years=year+s
# yeast=yeas+t
# yeasts=yeast+s
# yell=yel+l
# yelling=yell+ing
# yellow=yell+ow
# yelp=yel+p
# yelps=yelp+s
# yesteryear=yesteryea+r
# yield=yiel+d
# yielding=yield+ing
# yields=yield+s
# ymca=ymc+a
# yodel=yode+l
# yoga=yog+a
# yoke=yok+e
# yokel=yoke+l
# yokels=yokel+s
# yolk=yol+k
# yore=yor+e
# young=youn+g
# youngster=youngst+er
# youngsters=youngster+s
# youth=yout+h
# youths=youth+s
# yrs.=yrs+.
# yucca=yucc+a
# yuse=yus+e
# yyyy=yyy+y
# zeal=zea+l
# zealot=zealo+t
# zebra=zebr+a
# zenith=zenit+h
# zero=zer+o
# zeros=zero+s
# zest=zes+t
# zinc=zin+c
# zipper=zipp+er
# zlotys=zloty+s
# zombie=zombi+e
# zombies=zombie+s
# zone=zon+e
# zones=zone+s
# zoning=zon+ing
# zoologist=zoologis+t
# zoology=zoolog+y
# {0,t}={0,+t}

# %%
try:
    with open('brown_nouns.txt', 'r') as f:
        # Read words, strip whitespace, convert to lowercase, and get unique entries
        words = sorted(list(set([line.strip().lower() for line in f])))
    print(f"Successfully loaded {len(words)} unique words from brown_nouns.txt")
except FileNotFoundError:
    print("Error: brown_nouns.txt not found. Please make sure the file is in the correct directory.")
    words = [] # Set words to empty list to avoid crashing the script

class TrieNode:
    def __init__(self):
        self.children = {}
        self.word_end = False
        self.words_at_node = set()

class Trie:
    def __init__(self):
        self.root = TrieNode()
    def insert(self, word):
        node = self.root
        for char in word:
            if char not in node.children:
                node.children[char] = TrieNode()
            node = node.children[char]
            node.words_at_node.add(word)
        node.word_end = True
    def insert_reversed(self, word):
        node = self.root
        for char in word[::-1]:
            if char not in node.children:
                node.children[char] = TrieNode()
            node = node.children[char]
            node.words_at_node.add(word)
        node.word_end = True
    def split_stem_suffix(self, word, reverse=False):
        node = self.root
        branching_index = 0
        max_branch = 0
        traversed = []
        word_seq = word[::-1] if reverse else word
        for idx, char in enumerate(word_seq):
            traversed.append(char)
            node = node.children[char]
            branch_count = len(node.children)
            if branch_count > max_branch:
                max_branch = branch_count
                branching_index = idx + 1
        stem = word_seq[:branching_index]
        suffix = word_seq[branching_index:]
        stem = stem[::-1] if reverse else stem
        suffix = suffix[::-1] if reverse else suffix
        return stem, suffix, max_branch

prefix_trie = Trie()
suffix_trie = Trie()
for w in words:
    prefix_trie.insert(w)
    suffix_trie.insert_reversed(w)

prefix_results = []
suffix_results = []
prefix_frequencies = {}
suffix_frequencies = {}
for w in words:
    stem, suffix, freq = prefix_trie.split_stem_suffix(w)
    prefix_results.append({'word': w, 'stem': stem, 'suffix': suffix, 'freq': freq})
    if suffix:
        prefix_frequencies[suffix] = prefix_frequencies.get(suffix, 0)+1
    stem_s, suffix_s, freq_s = suffix_trie.split_stem_suffix(w, reverse=True)
    suffix_results.append({'word': w, 'stem': stem_s, 'suffix': suffix_s, 'freq': freq_s})
    if suffix_s:
        suffix_frequencies[suffix_s] = suffix_frequencies.get(suffix_s, 0)+1

import pandas as pd
import matplotlib.pyplot as plt
prefix_df = pd.DataFrame(prefix_results)
suffix_df = pd.DataFrame(suffix_results)

prefix_freq_series = pd.Series(prefix_frequencies)
suffix_freq_series = pd.Series(suffix_frequencies)

plt.figure(figsize=(10,5))
prefix_freq_series.sort_values(ascending=False)[:10].plot(kind='bar', alpha=0.5, color='blue', label='Prefix Trie Suffix')
suffix_freq_series.sort_values(ascending=False)[:10].plot(kind='bar', alpha=0.5, color='red', label='Suffix Trie Suffix')
plt.title('Suffix Frequency in Tries')
plt.xlabel('Suffix')
plt.ylabel('Frequency')
plt.legend()
plt.tight_layout()
plt.savefig('suffix_freq_plot.png')
prefix_df.to_csv('prefix_stem_suffix.csv', index=False)
suffix_df.to_csv('suffix_stem_suffix.csv', index=False)
# Out:
# Successfully loaded 17892 unique words from brown_nouns.txt

# %%
import pandas as pd
import matplotlib.pyplot as plt
import math # Added for entropy calculation (log)

# --- Load Data ---
try:
    with open('brown_nouns.txt', 'r') as f:
        # Read words, strip whitespace, convert to lowercase, and get unique entries
        words = sorted(list(set([line.strip().lower() for line in f])))
    print(f"Successfully loaded {len(words)} unique words from brown_nouns.txt")
except FileNotFoundError:
    print("Error: brown_nouns.txt not found. Please make sure the file is in the correct directory.")
    words = [] # Set words to empty list to avoid crashing the script

# --- Trie Data Structure ---
class TrieNode:
    def __init__(self):
        self.children = {}
        self.word_end = False
        self.words_at_node = set()

class Trie:
    def __init__(self):
        self.root = TrieNode()
        # Initialize total_nodes with 1 for the root node
        self.total_nodes = 1

    def insert(self, word):
        node = self.root
        for char in word:
            if char not in node.children:
                node.children[char] = TrieNode()
                self.total_nodes += 1 # Increment when a new node is created
            node = node.children[char]
            node.words_at_node.add(word)
        node.word_end = True

    def insert_reversed(self, word):
        node = self.root
        for char in word[::-1]:
            if char not in node.children:
                node.children[char] = TrieNode()
                self.total_nodes += 1 # Increment when a new node is created
            node = node.children[char]
            node.words_at_node.add(word)
        node.word_end = True

    def split_stem_suffix(self, word, reverse=False):
        node = self.root
        branching_index = 0
        max_branch = 0
        traversed = []
        word_seq = word[::-1] if reverse else word
        
        # Check if the word exists in the trie
        temp_node = self.root
        path_exists = True
        for char in word_seq:
            if char in temp_node.children:
                temp_node = temp_node.children[char]
            else:
                path_exists = False
                break
        if not path_exists:
             return (word, "", 0) if not reverse else (word, "", 0)


        for idx, char in enumerate(word_seq):
            traversed.append(char)
            node = node.children[char]
            branch_count = len(node.children)
            if branch_count > max_branch:
                max_branch = branch_count
                branching_index = idx + 1

        stem = "".join(word_seq[:branching_index])
        suffix = "".join(word_seq[branching_index:])

        if reverse:
            stem = stem[::-1]
            suffix = suffix[::-1]

        return stem, suffix, max_branch

    def calculate_metrics(self, inserted_words):
        """Calculates key metrics for the trie."""
        if not self.root.children:
            return {
                "Total Nodes": 1, "Average Depth": 0,
                "Average Branching Factor": 0, "Average Entropy": 0
            }

        # Average Depth is the average length of words inserted
        depths = [len(w) for w in inserted_words]
        avg_depth = sum(depths) / len(depths) if depths else 0

        branching_factors = []
        entropies = []
        
        # Use a stack for iterative DFS traversal to avoid recursion limits
        nodes_to_visit = [self.root]

        while nodes_to_visit:
            node = nodes_to_visit.pop()

            if not node.children:
                continue
            
            # Add children to the stack for the next iteration
            nodes_to_visit.extend(node.children.values())
            
            # --- Calculate Branching Factor ---
            branching_factors.append(len(node.children))

            # --- Calculate Entropy ---
            total_words_at_node = len(node.words_at_node)
            if total_words_at_node == 0:
                continue

            current_entropy = 0
            for child_node in node.children.values():
                prob = len(child_node.words_at_node) / total_words_at_node
                if prob > 0:
                    current_entropy -= prob * math.log2(prob)
            entropies.append(current_entropy)

        return {
            "Total Nodes": self.total_nodes,
            "Average Depth": avg_depth,
            "Average Branching Factor": sum(branching_factors) / len(branching_factors) if branching_factors else 0,
            "Average Entropy": sum(entropies) / len(entropies) if entropies else 0,
        }

# --- Build Tries ---
prefix_trie = Trie()
suffix_trie = Trie()
for w in words:
    prefix_trie.insert(w)
    suffix_trie.insert_reversed(w)

# --- Calculate and Display Metrics ---
print("\n" + "="*30)
print("TRIE METRICS")
print("="*30)

print("\n--- Prefix Trie Metrics ---")
prefix_metrics = prefix_trie.calculate_metrics(words)
for metric, value in prefix_metrics.items():
    # Print integers without decimals, floats with 4 decimal places
    print(f"{metric:<25}: {value if isinstance(value, int) else f'{value:.4f}'}")

print("\n--- Suffix Trie Metrics ---")
suffix_metrics = suffix_trie.calculate_metrics(words)
for metric, value in suffix_metrics.items():
    print(f"{metric:<25}: {value if isinstance(value, int) else f'{value:.4f}'}")
print("\n" + "="*30 + "\n")


# --- Perform Stem/Suffix Splitting ---
prefix_results = []
suffix_results = []
prefix_frequencies = {}
suffix_frequencies = {}

for w in words:
    stem, suffix, freq = prefix_trie.split_stem_suffix(w)
    prefix_results.append({'word': w, 'stem': stem, 'suffix': suffix, 'freq': freq})
    if suffix:
        prefix_frequencies[suffix] = prefix_frequencies.get(suffix, 0) + 1
        
    stem_s, suffix_s, freq_s = suffix_trie.split_stem_suffix(w, reverse=True)
    suffix_results.append({'word': w, 'stem': stem_s, 'suffix': suffix_s, 'freq': freq_s})
    if suffix_s:
        suffix_frequencies[suffix_s] = suffix_frequencies.get(suffix_s, 0) + 1

# --- Data Analysis and Visualization ---
prefix_df = pd.DataFrame(prefix_results)
suffix_df = pd.DataFrame(suffix_results)

prefix_freq_series = pd.Series(prefix_frequencies)
suffix_freq_series = pd.Series(suffix_frequencies)

plt.figure(figsize=(12, 6))
prefix_freq_series.sort_values(ascending=False)[:10].plot(kind='bar', alpha=0.7, color='blue', label='Prefix Trie Suffixes')
suffix_freq_series.sort_values(ascending=False)[:10].plot(kind='bar', alpha=0.5, color='red', label='Suffix Trie Suffixes')
plt.title('Top 10 Most Frequent Suffixes Identified by Tries')
plt.xlabel('Suffix')
plt.ylabel('Frequency (Count of Words with this Suffix)')
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.savefig('suffix_freq_plot.png')
print("Generated suffix frequency plot: 'suffix_freq_plot.png'")

prefix_df.to_csv('prefix_stem_suffix.csv', index=False)
suffix_df.to_csv('suffix_stem_suffix.csv', index=False)
print("Generated CSV outputs: 'prefix_stem_suffix.csv' and 'suffix_stem_suffix.csv'")
# Out:
# Successfully loaded 17892 unique words from brown_nouns.txt
#
# ==============================
# TRIE METRICS
# ==============================
#
# --- Prefix Trie Metrics ---
# Total Nodes              : 54977
# Average Depth            : 7.7919
# Average Branching Factor : 1.3067
# Average Entropy          : 0.2305
#
# --- Suffix Trie Metrics ---
# Total Nodes              : 57014
# Average Depth            : 7.7919
# Average Branching Factor : 1.3816
# Average Entropy          : 0.2409
#
# ==============================
#
# Generated suffix frequency plot: 'suffix_freq_plot.png'
# Generated CSV outputs: 'prefix_stem_suffix.csv' and 'suffix_stem_suffix.csv'
